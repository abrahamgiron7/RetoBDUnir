# %% [markdown]
# En este cuaderno se encuentra una adaptación del proceso de filtrado para que podáis trabajar con él y ver su funcionamiento más en detalle.
#
# Hay algunos ficheros que tendréis que poner en las carpetas que corresponda, por ejemplo todos los ficheros de frecuencias.

# %%
# !pip install spacy lingua-language-detector
# Out:
# Requirement already satisfied: spacy in c:\users\abrah\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: lingua-language-detector in c:\users\abrah\anaconda3\lib\site-packages (1.3.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (2.27.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: jinja2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (3.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: setuptools in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (58.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (8.2.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (1.9.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (0.3.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\abrah\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: regex<2024.0.0,>=2023.8.8 in c:\users\abrah\anaconda3\lib\site-packages (from lingua-language-detector) (2023.10.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: colorama in c:\users\abrah\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\abrah\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abrah\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)

# %%
# !tar -xvf freq.tar.xz
# !tar -xvf extract.tar.xz
# Out:
# x freq/fre/
# x freq/fre/fre-1gram.txt
# x freq/spa/spa-1gram.txt
# x freq/ger/
# x freq/spa/
# x freq/ita/ita-2gram.txt
# x freq/ita/ita-1gram.txt
# x freq/ger/ger-2gram.txt
# x freq/ger/ger-1gram.txt
# x freq/eng/
# x freq/
# x freq/eng/eng-2gram.txt
# x freq/ita/
# x freq/eng/eng-1gram.txt
# x freq/fre/fre-2gram.txt
# x freq/spa/spa-2gram.txt
# x extract/eng/occupational_therapy/
# x extract/spa/occupational_therapy/
# x extract/fre/occupational_therapy/
# x extract/spa/
# x extract/spa/occupational_therapy/terms.txt
# x extract/fre/occupational_therapy/terms.txt
# x extract/ger/occupational_therapy/terms.txt
# x extract/eng/
# x extract/ger/occupational_therapy/
# x extract/ita/
# x extract/eng/occupational_therapy/terms.txt
# x extract/ita/occupational_therapy/terms.txt
# x extract/fre/
# x extract/ita/occupational_therapy/
# x extract/ger/
# x extract/

# %%
# !spacy download en_core_web_sm
# !spacy download de_core_news_sm
# !spacy download fr_core_news_sm
# !spacy download it_core_news_sm
# !spacy download es_core_news_sm
# Out:
# Collecting en-core-web-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.0/en_core_web_sm-3.7.0-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from en-core-web-sm==3.7.0) (3.7.1)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (8.2.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.0.12)
# Requirement already satisfied: jinja2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.27.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.0.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.4.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.10.2)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.24.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.0.10)
# Requirement already satisfied: packaging>=20.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (21.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (4.64.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (58.0.4)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.3.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\abrah\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\abrah\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abrah\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->en-core-web-sm==3.7.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting de-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.7.0/de_core_news_sm-3.7.0-py3-none-any.whl (14.6 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from de-core-news-sm==3.7.0) (3.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.27.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (8.2.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (4.64.0)
# Requirement already satisfied: jinja2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.3.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.24.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: setuptools in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (58.0.4)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.10.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\abrah\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\abrah\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abrah\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from fr-core-news-sm==3.7.0) (3.7.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.64.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.3.3)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.27.1)
# Requirement already satisfied: setuptools in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (58.0.4)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (21.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: jinja2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: colorama in c:\users\abrah\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\abrah\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abrah\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# Collecting it-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-3.7.0/it_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from it-core-news-sm==3.7.0) (3.7.1)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (8.2.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (21.3)
# Requirement already satisfied: setuptools in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (58.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.10.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.9.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: jinja2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.24.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.27.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.3.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: colorama in c:\users\abrah\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\abrah\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abrah\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('it_core_news_sm')
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from es-core-news-sm==3.7.0) (3.7.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: jinja2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.9.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.27.1)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.10.2)
# Requirement already satisfied: setuptools in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (58.0.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (21.3)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.24.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.3.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\abrah\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abrah\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abrah\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abrah\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\abrah\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\abrah\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\abrah\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\abrah\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abrah\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
import time
import traceback
import uuid
import os
import spacy
import json

import lingua

# Spacy

spacy_models = json.loads('''{
	"bul": {"sm": null, "lg": null},
	"hrv": {"sm": "hr_core_news_sm", "lg": "hr_core_news_lg"},
	"cze": {"sm": null, "lg": null},
	"dan": {"sm": "da_core_news_sm", "lg": "da_core_news_trf"},
	"dut": {"sm": "nl_core_news_sm", "lg": "nl_core_news_lg"},
	"eng": {"sm": "en_core_web_sm", "lg": "en_core_web_trf"},
	"est": {"sm": null, "lg": null},
	"fin": {"sm": "fi_core_news_sm", "lg": "fi_core_news_lg"},
	"fre": {"sm": "fr_core_news_sm", "lg": "fr_dep_news_trf"},
	"ger": {"sm": "de_core_news_sm", "lg": "de_dep_news_trf"},
	"gre": {"sm": "el_core_news_sm", "lg": "el_core_news_lg"},
	"hun": {"sm": null, "lg": null},
	"gle": {"sm": null, "lg": null},
	"ita": {"sm": "it_core_news_sm", "lg": "it_core_news_lg"},
	"lav": {"sm": null, "lg": null},
	"lit": {"sm": "lt_core_news_sm", "lg": "lt_core_news_lg"},
	"mlt": {"sm": null, "lg": null},
	"pol": {"sm": "pl_core_news_sm", "lg": "pl_core_news_lg"},
	"por": {"sm": "pt_core_news_sm", "lg": "pt_core_news_lg"},
	"rum": {"sm": "ro_core_news_sm", "lg": "ro_core_news_lg"},
	"rus": {"sm": "ru_core_news_sm", "lg": "ru_core_news_lg"},
	"slo": {"sm": null, "lg": null},
	"slv": {"sm": null, "lg": null},
	"spa": {"sm": "es_core_news_sm", "lg": "es_dep_news_trf"},
	"swe": {"sm": null, "lg": null}
}''')



freq_list = {"spa": {}, "ger": {}, "fre": {}, "eng": {}, "ita": {}}

freq_list["spa"]["1-gram"] = open("./freq/spa/spa-1gram.txt", encoding="utf8").read().split("\n")
freq_list["ger"]["1-gram"] = open("./freq/ger/ger-1gram.txt", encoding="utf8").read().split("\n")
freq_list["fre"]["1-gram"] = open("./freq/fre/fre-1gram.txt", encoding="utf8").read().split("\n")
freq_list["eng"]["1-gram"] = open("./freq/eng/eng-1gram.txt", encoding="utf8").read().split("\n")
freq_list["ita"]["1-gram"] = open("./freq/ita/ita-1gram.txt", encoding="utf8").read().split("\n")

freq_list["spa"]["2-gram"] = open("./freq/spa/spa-2gram.txt", encoding="utf8").read().split("\n")
freq_list["ger"]["2-gram"] = open("./freq/ger/ger-2gram.txt", encoding="utf8").read().split("\n")
freq_list["fre"]["2-gram"] = open("./freq/fre/fre-2gram.txt", encoding="utf8").read().split("\n")
freq_list["eng"]["2-gram"] = open("./freq/eng/eng-2gram.txt", encoding="utf8").read().split("\n")
freq_list["ita"]["2-gram"] = open("./freq/ita/ita-2gram.txt", encoding="utf8").read().split("\n")

lingua_langs = {
		"eng": lingua.Language.ENGLISH,
		"spa": lingua.Language.SPANISH,
		"ita": lingua.Language.ITALIAN,
		"ger": lingua.Language.GERMAN,
		"fre": lingua.Language.FRENCH
	}

langs_used = [v for k,v in lingua_langs.items()]

lang_detector = lingua.LanguageDetectorBuilder.from_languages(*langs_used).build()

# %%
#Gold: Glosario de referencia revisado
gold_data_eng = json.loads(open("gold_occupational_therapy_eng.json").read())
gold_data_fre = json.loads(open("gold_occupational_therapy_fre.json").read())
gold_data_spa = json.loads(open("gold_occupational_therapy_spa.json").read())
gold_data_ger = json.loads(open("gold_occupational_therapy_ger.json").read())

gold_terms_eng = [term['forms']['eng'][0]['text'] for term in gold_data_eng]
gold_terms_fre = [term['forms']['fre'][0]['text'] for term in gold_data_fre]
gold_terms_spa = [term['forms']['spa'][0]['text'] for term in gold_data_spa]
gold_terms_ger = [term['forms']['ger'][0]['text'] for term in gold_data_ger]

def MatrizConfusion(terminos_raw, idioma, paso_actual):
    import numpy as np
    array_raw = np.array(terminos_raw)
    if idioma == "eng":
        array_gold = np.array(gold_terms_eng)
    elif idioma == "fre":
        array_gold = np.array(gold_terms_fre)        
    elif idioma == "spa":    
        array_gold = np.array(gold_terms_spa)        
    elif idioma == "ger":          
        array_gold = np.array(gold_terms_ger)
    else:
        print("ERROR: Idioma no reconocido")
        
    # Inicializa los contadores de TP, FP, TN y FN en 0
    TP = 0 #Están en ambos arrays
    TN = 0 #No se puede calcular?
    FP = 0 #Están en raw pero no en gold
    FN = 0 #No están en raw pero si en gold

    # Comparar los valores en los dos arrays
    for extraido in array_raw:
        #print("extraido: ")
        #print(extraido)
        for valido in array_gold:
            #print(valido)
            if extraido == valido:
                TP += 1

    FP = len(array_raw) - TP

    FN = len(array_gold) - TP

    # Crear la matriz de confusión
    matriz_confusion = [[TP, FP], [TN, FN]]
    
    print("Estamos en el paso: " + paso_actual)
    print("Idioma: " + idioma)
    print("Matriz de Confusión:")
    print("|TP|FP|")
    print("|TN|FN|\n")

    for fila in matriz_confusion:
        print(fila)

    #Precisión: Porcentaje de predicciones positivas correctas
    P=TP/(FP+TP)*100

    #Sensibilidad: Porcentaje de casos positivos detectados
    S=TP/(TP+FN)*100

    print("\nPrecisión (%):")
    print(P)

    print("\nSensibilidad (%):")
    print(S)
    
    print("\n----------------------------------------------------------------------------\n")

# %%
def filter_terms(lines, lang):

	terms = {}

	filter_deep_1g = 50000
	filter_deep_2g = 1000000

	dict_1g = {}
	dict_2g = {}
    

	if (lang in freq_list) and ("1-gram" in freq_list[lang]):

		lower_list = [t.lower() for t in freq_list[lang]["1-gram"][:filter_deep_1g]] #No entiendo que hace filter...

		dict_1g = dict(zip(lower_list, range(len(lower_list))))
        
	if (lang in freq_list) and ("2-gram" in freq_list[lang]):

		lower_list = [t.lower() for t in freq_list[lang]["2-gram"][:filter_deep_2g]]

		dict_2g = dict(zip(lower_list, range(len(lower_list))))
        
	for term in lines:

		freq, term = term.replace("\n", "").split("\t") #numero es la freq y la palabra el term (la separa y limpia)

		term = term.replace("-", " ").replace("  ", " ") #Elimina los guiones por espacios

		if (lang in freq_list) and ("1-gram" in freq_list[lang]) and (term.lower() in dict_1g):

			#print("Excluding", term, "(too freq 1-gram)")
			pass

		elif (lang in freq_list) and ("2-gram" in freq_list[lang]) and (term.lower() in dict_2g):

			#print("Excluding", term, "(too freq 2-gram)")
			pass
            #Filtrado en función frecuencias (paso)


		elif any(len(word) < 4 for word in term.split(" ")):

			#print("Excluding", term, "(too short)")
			pass

		elif not term.replace(" ", "").replace("'", "").replace("-","").isalpha() or term.replace(" ", "").startswith("-") or term.replace(" ", "").endswith("-"):

			#print("Excluding", term, "(strange symbols)")
			pass
            #Ultimo paso terminos cortos y que no es texto sino que tiene caracteres extraños (paso arriba)

		else:

			#print("Adding", term)
			terms[term] = {"f": freq}

	#PASO 1-------------------------------------------------------------
	#Calculamos matriz de confusión (Abraham)
	terms_key = list(terms.keys())

	MatrizConfusion(terms_key, lang, "Paso de filtrado 1")
	#-------------------------------------------------------------------            

# Las diferencias de capitalizacion se resuelven optando por la version mas habitual

	for term, obj in terms.copy().items():

		if term.lower() != term and term.lower() in terms:

			if int(terms[term.lower()]["f"]) > int(terms[term]["f"]):

				terms.pop(term)

				#print("Excluding", term, "(duplicated and less frequent capitalization)")

			else:

				terms.pop(term.lower())

				#print("Excluding", term.lower(), "(duplicated and less frequent capitalization)")
                #Términos que tienen diferentes lugares de uso y primera en mayus o minus (otro paso)

	#PASO 2-------------------------------------------------------------
	#Calculamos matriz de confusión (Abraham)
	terms_key = list(terms.keys())

	MatrizConfusion(terms_key, lang, "Paso de filtrado 2")
	#-------------------------------------------------------------------    

	valid_NE = ["EVENT", "FAC", "ORG", "WORK_OF_ART"]

	pipe = spacy.load(spacy_models[lang]["sm"])

	for term, obj in terms.copy().items():

		doc = pipe(term)

		for token in doc.ents:

			#print("Found NE: ", token.text, token.label_)

			if not (token.label_ in valid_NE) and term in terms:

				terms.pop(term)
                #Filtrando si son parte de entidades nombradas (paso)
	#PASO 3-------------------------------------------------------------
	#Calculamos matriz de confusión (Abraham)
	terms_key = list(terms.keys())

	MatrizConfusion(terms_key, lang, "Paso de filtrado 3")
	#-------------------------------------------------------------------    

	for term, obj in terms.copy().items():

		detected = lang_detector.detect_language_of(term)

		#print(term, detected)

		if lang in lingua_langs and detected != lingua_langs[lang]:

			terms.pop(term)

#PASO 4-------------------------------------------------------------
	#Calculamos matriz de confusión (Abraham)
	terms_key = list(terms.keys())

	MatrizConfusion(terms_key, lang, "Paso de filtrado 4")
	#-------------------------------------------------------------------    

	return terms

# %%
def lemmatize_terms(terms, lang):

	lemmatized_terms = {}

	pipe = spacy.load(spacy_models[lang]["sm"])

	term_list_old = list(terms.keys())

	for term in term_list_old:

		doc = pipe(term)

		full_token = []

		for token in doc:

			full_token.append(token.lemma_)

		lemma = " ".join(full_token)

		if term in terms:

			old_f = terms[term]

			if lemma in lemmatized_terms:

				current_f = lemmatized_terms[lemma]

				new_f = current_f["f"] + old_f["f"] # Varias palabras convergen en una raíz

				lemmatized_terms[lemma] = {"f": new_f}

			else:

				lemmatized_terms[lemma] = {"f": old_f["f"]}

	# Se reaplica filtrado a las palabras luego de filtrarlas, esto estaría
  # mejor hacerlo de otra forma, hay código repetido

	filter_deep_1g = 25000
	filter_deep_2g = 1000000

	dict_1g = {}
	dict_2g = {}

	if (lang in freq_list) and ("1-gram" in freq_list[lang]):

		lower_list = [t.lower() for t in freq_list[lang]["1-gram"][:filter_deep_1g]]

		dict_1g = dict(zip(lower_list, range(len(lower_list))))

	if (lang in freq_list) and ("2-gram" in freq_list[lang]):

		lower_list = [t.lower() for t in freq_list[lang]["2-gram"][:filter_deep_2g]]

		dict_2g = dict(zip(lower_list, range(len(lower_list))))


	for term in lemmatized_terms.copy().keys():

    # Solo se extá empleando en "eng" porque la lematización en otras cambia
    # también otras flexiones y es algo a evitar.

		if lang == "eng":

			if (term.lower() in dict_1g):

				#print("Excluding", term, "(too freq 1-gram) lemma")

				lemmatized_terms.pop(term)

			elif (term.lower() in dict_2g):

				#print("Excluding", term, "(too freq 2-gram) lemma")

				lemmatized_terms.pop(term)

#PASO 5-------------------------------------------------------------
	#Calculamos matriz de confusión (Abraham)
	terms_key = list(lemmatized_terms.keys())

	MatrizConfusion(terms_key, lang, "Paso de filtrado 5 (POST-LEMATIZACIÓN)")
#-------------------------------------------------------------------    

	return lemmatized_terms

# %%
#Inglés
example = open("./extract/eng/occupational_therapy/terms.txt", encoding="utf8").readlines()

terms = filter_terms(example, "eng")

#print(terms)

terms = lemmatize_terms(terms, "eng")

#print(terms)
# Out:
# Estamos en el paso: Paso de filtrado 1
# Idioma: eng
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [401, 1295]
# [0, 348]
#
# Precisión (%):
# 23.6438679245283
#
# Sensibilidad (%):
# 53.538050734312414
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 2
# Idioma: eng
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [393, 1241]
# [0, 356]
#
# Precisión (%):
# 24.05140758873929
#
# Sensibilidad (%):
# 52.46995994659546
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 3
# Idioma: eng
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [383, 1122]
# [0, 366]
#
# Precisión (%):
# 25.448504983388702
#
# Sensibilidad (%):
# 51.134846461949266
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 4
# Idioma: eng
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [344, 919]
# [0, 405]
#
# Precisión (%):
# 27.23673792557403
#
# Sensibilidad (%):
# 45.92790387182911
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 5 (POST-LEMATIZACIÓN)
# Idioma: eng
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [537, 657]
# [0, 212]
#
# Precisión (%):
# 44.9748743718593
#
# Sensibilidad (%):
# 71.69559412550068
#
# ----------------------------------------------------------------------------

# %%
#Francés
example = open("./extract/fre/occupational_therapy/terms.txt", encoding="utf8").readlines()

terms = filter_terms(example, "fre")

#print(terms)

terms = lemmatize_terms(terms, "fre")

#print(terms)
# Out:
# Estamos en el paso: Paso de filtrado 1
# Idioma: fre
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [92, 1577]
# [0, 51]
#
# Precisión (%):
# 5.512282804074296
#
# Sensibilidad (%):
# 64.33566433566433
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 2
# Idioma: fre
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [91, 1529]
# [0, 52]
#
# Precisión (%):
# 5.617283950617284
#
# Sensibilidad (%):
# 63.63636363636363
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 3
# Idioma: fre
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [91, 1164]
# [0, 52]
#
# Precisión (%):
# 7.250996015936255
#
# Sensibilidad (%):
# 63.63636363636363
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 4
# Idioma: fre
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [90, 925]
# [0, 53]
#
# Precisión (%):
# 8.866995073891626
#
# Sensibilidad (%):
# 62.93706293706294
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 5 (POST-LEMATIZACIÓN)
# Idioma: fre
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [76, 905]
# [0, 67]
#
# Precisión (%):
# 7.747196738022426
#
# Sensibilidad (%):
# 53.14685314685315
#
# ----------------------------------------------------------------------------

# %%
#Alemán
example = open("./extract/ger/occupational_therapy/terms.txt", encoding="utf8").readlines()

terms = filter_terms(example, "ger")

#print(terms)

terms = lemmatize_terms(terms, "ger")

#print(terms)
# Out:
# Estamos en el paso: Paso de filtrado 1
# Idioma: ger
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [134, 1898]
# [0, 9]
#
# Precisión (%):
# 6.594488188976378
#
# Sensibilidad (%):
# 93.7062937062937
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 2
# Idioma: ger
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [134, 1893]
# [0, 9]
#
# Precisión (%):
# 6.610754810064135
#
# Sensibilidad (%):
# 93.7062937062937
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 3
# Idioma: ger
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [134, 1208]
# [0, 9]
#
# Precisión (%):
# 9.985096870342772
#
# Sensibilidad (%):
# 93.7062937062937
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 4
# Idioma: ger
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [134, 1076]
# [0, 9]
#
# Precisión (%):
# 11.074380165289256
#
# Sensibilidad (%):
# 93.7062937062937
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 5 (POST-LEMATIZACIÓN)
# Idioma: ger
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [67, 1090]
# [0, 76]
#
# Precisión (%):
# 5.790838375108038
#
# Sensibilidad (%):
# 46.85314685314685
#
# ----------------------------------------------------------------------------

# %%
#Español
example = open("./extract/spa/occupational_therapy/terms.txt", encoding="utf8").readlines()

terms = filter_terms(example, "spa")

#print(terms)

terms = lemmatize_terms(terms, "spa")

#print(terms)
# Out:
# Estamos en el paso: Paso de filtrado 1
# Idioma: spa
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [88, 2765]
# [0, 29]
#
# Precisión (%):
# 3.0844724851034
#
# Sensibilidad (%):
# 75.21367521367522
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 2
# Idioma: spa
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [82, 2674]
# [0, 35]
#
# Precisión (%):
# 2.9753265602322205
#
# Sensibilidad (%):
# 70.08547008547008
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 3
# Idioma: spa
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [82, 1469]
# [0, 35]
#
# Precisión (%):
# 5.286911669890394
#
# Sensibilidad (%):
# 70.08547008547008
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 4
# Idioma: spa
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [81, 1144]
# [0, 36]
#
# Precisión (%):
# 6.612244897959184
#
# Sensibilidad (%):
# 69.23076923076923
#
# ----------------------------------------------------------------------------
#
# Estamos en el paso: Paso de filtrado 5 (POST-LEMATIZACIÓN)
# Idioma: spa
# Matriz de Confusión:
# |TP|FP|
# |TN|FN|
#
# [84, 1113]
# [0, 33]
#
# Precisión (%):
# 7.017543859649122
#
# Sensibilidad (%):
# 71.7948717948718
#
# ----------------------------------------------------------------------------

# %%
#Italiano
example = open("./extract/ita/occupational_therapy/terms.txt", encoding="utf8").readlines()

terms = filter_terms(example, "ita")

#print(terms)

terms = lemmatize_terms(terms, "ita")

#print(terms)
# Out:
# ERROR: Idioma no reconocido
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [82], in <cell line: 4>()
#       1 #Italiano
#       2 example = open("./extract/ita/occupational_therapy/terms.txt", encoding="utf8").readlines()
# ----> 4 terms = filter_terms(example, "ita")
#       6 #print(terms)
#       8 terms = lemmatize_terms(terms, "ita")
#
# Input In [68], in filter_terms(lines, lang)
#      58 	#PASO 1-------------------------------------------------------------
#      59 	#Calculamos matriz de confusión (Abraham)
#      60 	terms_key = list(terms.keys())
# ---> 62 	MatrizConfusion(terms_key, lang, "Paso de filtrado 1")
#      63 	#-------------------------------------------------------------------
#      64
#      65 # Las diferencias de capitalizacion se resuelven optando por la version mas habitual
#      67 	for term, obj in terms.copy().items():
#
# Input In [70], in MatrizConfusion(terminos_raw, idioma, paso_actual)
#      32 # Comparar los valores en los dos arrays
#      33 for extraido in array_raw:
#      34     #print("extraido: ")
#      35     #print(extraido)
# ---> 36     for valido in array_gold:
#      37         #print(valido)
#      38         if extraido == valido:
#      39             TP += 1
#
# UnboundLocalError: local variable 'array_gold' referenced before assignment

# %%
print(filter_terms(example, "ita"))
# Out:
# Excluding classe (too freq 1-gram)
# Excluding bambini (too freq 1-gram)
# Excluding $ (too short)
# Excluding risultati (too freq 1-gram)
# Excluding attività (too freq 1-gram)
# Excluding DCD (too short)
# Excluding sviluppo (too freq 1-gram)
# Excluding funzioni (too freq 1-gram)
# Excluding evoluzione (too freq 1-gram)
# Excluding allievi (too freq 1-gram)
# Excluding classi (too freq 1-gram)
# Adding motricità
# Excluding difficoltà (too freq 1-gram)
# Adding funzioni esecutive
# Excluding scrittura (too freq 1-gram)
# Excluding categorie (too freq 1-gram)
# Excluding età (too short)
# Excluding controllo (too freq 1-gram)
# Excluding p<0.01 (strange symbols)
# Excluding abilità (too freq 1-gram)
# Excluding attenzione (too freq 1-gram)
# Excluding disturbi (too freq 1-gram)
# Excluding valutazione (too freq 1-gram)
# Excluding interno (too freq 1-gram)
# Excluding M. (too short)
# Excluding scuola (too freq 1-gram)
# Excluding J. (too short)
# Excluding problemi (too freq 1-gram)
# Excluding motorie (too freq 1-gram)
# Adding Lietta Santinelli
# Excluding $ $ (too short)
# Excluding Cl (too short)
# Excluding programma (too freq 1-gram)
# Excluding anni (too freq 1-gram)
# Excluding genitori (too freq 1-gram)
# Excluding coordinazione (too freq 1-gram)
# Excluding apprendimento (too freq 1-gram)
# Excluding livello (too freq 1-gram)
# Excluding modo (too freq 1-gram)
# Excluding A. (too short)
# Adding publication
# Adding CITATIONS
# Excluding intervento (too freq 1-gram)
# Adding children
# Excluding gruppo (too freq 1-gram)
# Excluding Disturbo (too freq 1-gram)
# Excluding categoria (too freq 1-gram)
# Adding coordinazione motoria
# Excluding caratteri (too freq 1-gram)
# Excluding adolescenza (too freq 1-gram)
# Excluding infanzia (too freq 1-gram)
# Excluding J (too short)
# Adding View
# Excluding organizzazione (too freq 1-gram)
# Excluding rapidità (too freq 1-gram)
# Adding valutazione iniziale
# Excluding studio (too freq 1-gram)
# Excluding L. (too short)
# Excluding equilibrio (too freq 1-gram)
# Excluding bambino (too freq 1-gram)
# Adding Child
# Excluding parte (too freq 1-gram)
# Excluding vita (too freq 1-gram)
# Excluding presenza (too freq 1-gram)
# Excluding insegnanti (too freq 1-gram)
# Excluding rapidità di scrittura (too short)
# Excluding relazione (too freq 1-gram)
# Adding Ergoterapia
# Excluding S. (too short)
# Excluding soggetti (too freq 1-gram)
# Excluding ritardo (too freq 1-gram)
# Excluding Sviluppo (too freq 1-gram)
# Adding attività fisica
# Excluding CITATIONS SEE (too short)
# Excluding Coordinazione (too freq 1-gram)
# Excluding docenti (too freq 1-gram)
# Excluding Motoria (too freq 1-gram)
# Excluding pianificazione (too freq 1-gram)
# Adding programma motorio
# Excluding ﬁne (too short)
# Excluding compiti (too freq 1-gram)
# Excluding stimolazione (too freq 1-gram)
# Excluding iniziativa (too freq 1-gram)
# Adding PUBLICATIONS
# Adding controllo emotivo
# Excluding SEE PROFILE (too short)
# Excluding progetto (too freq 1-gram)
# Excluding rischio (too freq 1-gram)
# Excluding Lie5a$San8nelli,$Laura$Rodesino$2013,$ www.ergoterapiapediatrica.ch$ (strange symbols)
# Excluding $ $ $ (too short)
# Excluding Attenzione (too freq 1-gram)
# Excluding disturbo (too freq 1-gram)
# Excluding numero (too freq 1-gram)
# Adding pianiﬁcazione
# Adding Coordination Disorder
# Excluding test (too freq 1-gram)
# Excluding T1 (too short)
# Excluding collaborazione (too freq 1-gram)
# Adding motricità fine
# Excluding minuto (too freq 1-gram)
# Excluding E. (too short)
# Excluding risultato (too freq 1-gram)
# Excluding partecipazione (too freq 1-gram)
# Excluding movimento (too freq 1-gram)
# Adding authors
# Excluding T2 (too short)
# Excluding performance (too freq 1-gram)
# Excluding mesi (too freq 1-gram)
# Excluding D. (too short)
# Adding physical
# Excluding school (too freq 1-gram)
# Excluding K. (too short)
# Adding pretermine
# Excluding Questionario (too freq 1-gram)
# Excluding bambini con problemi (too short)
# Excluding esempio (too freq 1-gram)
# Excluding termine (too freq 1-gram)
# Excluding motricità ﬁne (too short)
# Excluding monitoraggio (too freq 1-gram)
# Adding coordination
# Excluding D (too short)
# Excluding analisi (too freq 1-gram)
# Excluding G. (too short)
# Excluding quadro (too freq 1-gram)
# Excluding Centro (too freq 1-gram)
# Excluding Journal (too freq 1-gram)
# Excluding prestazioni (too freq 1-gram)
# Excluding F. (too short)
# Excluding base (too freq 1-gram)
# Adding problemi psicopatologici
# Excluding popolazione (too freq 1-gram)
# Excluding on (too short)
# Excluding dati (too freq 1-gram)
# Adding QUFE
# Adding abilità motorie
# Excluding funzionamento (too freq 1-gram)
# Adding preterm
# Excluding NSS (too short)
# Excluding compito (too freq 1-gram)
# Excluding allenamento (too freq 1-gram)
# Excluding legame (too freq 1-gram)
# Excluding lavoro (too freq 1-gram)
# Excluding nascita (too freq 1-gram)
# Adding related
# Excluding comportamenti (too freq 1-gram)
# Excluding Confronto (too freq 1-gram)
# Excluding p<0.05 (strange symbols)
# Excluding Figura (too freq 1-gram)
# Excluding particolare (too freq 1-gram)
# Excluding Controllo (too freq 1-gram)
# Adding Children
# Excluding sistema (too freq 1-gram)
# Adding Comorbidità
# Adding ﬂessibilità
# Excluding P. (too short)
# Excluding TOL (too short)
# Excluding studi (too freq 1-gram)
# Excluding T. (too short)
# Adding Movement
# Adding categorie motricità
# Excluding situazione (too freq 1-gram)
# Excluding minuti (too freq 1-gram)
# Adding Developmental
# Excluding C. (too short)
# Excluding periodo (too freq 1-gram)
# Adding Exercise
# Excluding University (too freq 1-gram)
# Excluding R. (too short)
# Excluding � (too short)
# Excluding giorno (too freq 1-gram)
# Excluding vita quotidiana (too freq 2-gram)
# Excluding gruppo di controllo (too short)
# Excluding All (too short)
# Adding modo significativo
# Excluding fine (too freq 1-gram)
# Excluding ricerche (too freq 1-gram)
# Adding categoria equilibrio
# Excluding scolas1co (strange symbols)
# Adding Controllo emotivo
# Excluding Approcci (too freq 1-gram)
# Adding Occupational
# Adding aPvità
# Adding Centro Ergoterapia
# Excluding numero di caratteri (too short)
# Excluding confronto (too freq 1-gram)
# Adding modo signiﬁcativo
# Excluding MND (too short)
# Adding Therapy
# Adding stats
# Excluding Organizzazione (too freq 1-gram)
# Excluding disfunzione (too freq 1-gram)
# Adding coltà
# Excluding Hum (too short)
# Adding function
# Adding inattenzione
# Adding Inibizione Flessibilità
# Excluding ∆ (too short)
# Excluding page was (too short)
# Adding Comorbidità psicopatologica
# Adding author
# Excluding user has (too short)
# Excluding KIT (too short)
# Adding Santinelli Centro
# Excluding N. (too short)
# Excluding esame (too freq 1-gram)
# Excluding Health (too freq 1-gram)
# Adding READS
# Excluding tendenza (too freq 1-gram)
# Adding Sallis
# Excluding femmine (too freq 1-gram)
# Adding birth
# Adding requested
# Excluding flessibilità (too freq 1-gram)
# Adding physical activity
# Excluding depressione (too freq 1-gram)
# Excluding See discussions (too short)
# Excluding palla (too freq 1-gram)
# Adding comorbidità
# Adding Henderson
# Excluding PROFILE All (too short)
# Excluding Michele (too freq 1-gram)
# Adding quadri clinici
# Excluding Mov (too short)
# Excluding Science (too freq 1-gram)
# Adding stimolazione motoria
# Excluding allievo (too freq 1-gram)
# Excluding All content (too short)
# Excluding esecuzione (too freq 1-gram)
# Adding iperattività
# Excluding Funzioni (too freq 1-gram)
# Excluding difficoltà di coordinazione (too short)
# Excluding ergoterapis1 (strange symbols)
# Adding working
# Excluding esperienza (too freq 1-gram)
# Excluding incremento (too freq 1-gram)
# Excluding compromissione (too freq 1-gram)
# Excluding ambito (too freq 1-gram)
# Adding View publication
# Excluding abilità di motricità (too short)
# Excluding p=0.01 (strange symbols)
# Excluding Pianificazione (too freq 1-gram)
# Adding classe stimolata
# Excluding inibizione (too freq 1-gram)
# Adding following
# Excluding media (too freq 1-gram)
# Excluding publication at (too short)
# Excluding by (too short)
# Adding academic
# Excluding acquisizione (too freq 1-gram)
# Adding Developmental Coordination
# Adding situazione iniziale
# Excluding impressione (too freq 1-gram)
# Excluding H. (too short)
# Adding Physical
# Adding disturbi esternalizzanti
# Adding Sugden
# Excluding settimana (too freq 1-gram)
# Excluding effetti (too freq 1-gram)
# Excluding risoluzione (too freq 1-gram)
# Excluding questionari (too freq 1-gram)
# Excluding Monte (too freq 1-gram)
# Adding sviluppo motorio
# Excluding Monitoraggio (too freq 1-gram)
# Excluding osservazione (too freq 1-gram)
# Excluding Davis (too freq 1-gram)
# Excluding scopo (too freq 1-gram)
# Excluding Hum Mov (too short)
# Adding sePng
# Adding ﬂessione
# Excluding competenza (too freq 1-gram)
# Excluding aspetti (too freq 1-gram)
# Excluding sintomi (too freq 1-gram)
# Excluding importanza (too freq 1-gram)
# Excluding qualità (too freq 1-gram)
# Excluding riconoscimento (too freq 1-gram)
# Excluding fattori (too freq 1-gram)
# Excluding Hadders Algra M. (too short)
# Adding Develop
# Excluding quadro clinico (too freq 2-gram)
# Adding Pediatrics
# Excluding low (too short)
# Excluding ricerca (too freq 1-gram)
# Excluding comportamento (too freq 1-gram)
# Excluding between (too freq 1-gram)
# Excluding rendimento (too freq 1-gram)
# Adding difficoltà motorie
# Adding Neurol
# Excluding Piek JP (too short)
# Excluding review (too freq 1-gram)
# Adding allenamento motorio
# Excluding evidenze (too freq 1-gram)
# Excluding L (too short)
# Excluding scuole (too freq 1-gram)
# Excluding problem (too freq 1-gram)
# Excluding classe di controllo (too short)
# Excluding via (too short)
# Excluding caratteristiche (too freq 1-gram)
# Adding legame positivo
# Excluding contesti (too freq 1-gram)
# Excluding punto (too freq 1-gram)
# Excluding fattore (too freq 1-gram)
# Excluding difficoltà di apprendimento (too short)
# Adding Dwyer
# Excluding giornata (too freq 1-gram)
# Adding scuola regolare
# Excluding velocità (too freq 1-gram)
# Adding comportamenti esternalizzanti
# Excluding categorie motricità ﬁne (too short)
# Excluding complicanze (too freq 1-gram)
# Adding Carasso
# Excluding criterio (too freq 1-gram)
# Excluding Sciences (too freq 1-gram)
# Excluding Mov Sci (too short)
# Adding segni neurologici minori
# Excluding ABC (too short)
# Excluding Law (too short)
# Excluding School (too freq 1-gram)
# Excluding kit (too short)
# Excluding traiettoria (too freq 1-gram)
# Adding intervento specialistico
# Excluding trad (too freq 1-gram)
# Adding disturbi psicopatologici
# Excluding limiti (too freq 1-gram)
# Adding categoria palla
# Adding criterio diagnostico
# Adding relationship
# Excluding confronti (too freq 1-gram)
# Adding goffaggine
# Adding Beery
# Excluding Svizzera (too freq 1-gram)
# Excluding tipo (too freq 1-gram)
# Excluding sport (too freq 1-gram)
# Excluding Study (too freq 1-gram)
# Excluding 0.73 (strange symbols)
# Excluding Firenze (too freq 1-gram)
# Excluding aPvità scolas1che (strange symbols)
# Excluding modalità (too freq 1-gram)
# Excluding DOI (too short)
# Excluding Test (too freq 1-gram)
# Adding programma motorio quotidiano
# Excluding ansia (too freq 1-gram)
# Excluding campione (too freq 1-gram)
# Excluding limitazioni (too freq 1-gram)
# Excluding Par1cipa1on (strange symbols)
# Adding esternalizzanti
# Adding Ergoterapia Pediatrica
# Excluding peso (too freq 1-gram)
# Excluding carico (too freq 1-gram)
# Excluding progresso (too freq 1-gram)
# Adding Switzerland
# Adding Marzocchi
# Excluding Attività (too freq 1-gram)
# Excluding prestazione (too freq 1-gram)
# Adding Shephard
# Adding Exercise Science
# Adding grafo
# Excluding Education (too freq 1-gram)
# Adding Applied Sciences
# Excluding motori (too freq 1-gram)
# Excluding gestazione (too freq 1-gram)
# Adding motricità globale
# Excluding from (too freq 1-gram)
# Adding problemi psicopatologici lievi
# Excluding prevenzione (too freq 1-gram)
# Excluding squadra (too freq 1-gram)
# Adding evoluzione signiﬁcativa
# Adding QUFE Genitori
# Excluding motivazione (too freq 1-gram)
# Excluding esecuzione di aPvità (too short)
# Excluding TO (too short)
# Excluding Med (too short)
# Excluding sostegno (too freq 1-gram)
# Excluding applicabilità (too freq 1-gram)
# Excluding sintomatologia (too freq 1-gram)
# Excluding Occupa1onal Therapy (strange symbols)
# Adding ergoterapia
# Excluding B. (too short)
# Adding Psychiatry
# Excluding cura (too freq 1-gram)
# Excluding Scuola (too freq 1-gram)
# Adding Ontario
# Excluding successo (too freq 1-gram)
# Excluding settimana di gestazione (too short)
# Excluding educazione (too freq 1-gram)
# Adding Child Neurol
# Excluding memoria (too freq 1-gram)
# Excluding memoria di lavoro (too short)
# Adding risultati scolastici
# Excluding lezioni (too freq 1-gram)
# Excluding ripercussioni (too freq 1-gram)
# Adding learning
# Excluding > (too short)
# Adding February
# Excluding Integrazione (too freq 1-gram)
# Adding problem solving
# Excluding competenze (too freq 1-gram)
# Excluding corpo (too freq 1-gram)
# Excluding American (too freq 1-gram)
# Excluding Graham (too freq 1-gram)
# Adding complicanze psicopatologiche
# Excluding ∆ classe (too short)
# Excluding schizofrenia (too freq 1-gram)
# Excluding Lane (too freq 1-gram)
# Excluding Rieducazione (too freq 1-gram)
# Excluding causa (too freq 1-gram)
# Excluding THERAPY KIT (too short)
# Excluding vulnerabilità (too freq 1-gram)
# Adding funzioni motorie
# Excluding May (too short)
# Adding Michele Poletti
# Adding Assessment Battery
# Excluding generalizzazione (too freq 1-gram)
# Excluding aspetto (too freq 1-gram)
# Adding weight
# Excluding transfert (too freq 1-gram)
# Excluding svolgimento (too freq 1-gram)
# Adding FINE MOTOR
# Excluding peggioramento (too freq 1-gram)
# Adding Psychological
# Adding Funzioni Esecutive
# Adding competenze posturali
# Excluding precauzione (too freq 1-gram)
# Excluding fibre (too freq 1-gram)
# Excluding STUDY ON (too short)
# Excluding self (too freq 1-gram)
# Adding tipo internalizzante
# Adding Michele Mainardi
# Excluding gesto (too freq 1-gram)
# Excluding esercizi (too freq 1-gram)
# Excluding periodo di stimolazione (too short)
# Excluding Develop Med (too short)
# Excluding età media (too short)
# Excluding Performance (too freq 1-gram)
# Adding sostanza bianca
# Adding ability
# Adding MOTOR SKILLS
# Excluding p=0.6 (strange symbols)
# Excluding anni di età (too short)
# Excluding fattore di rischio (too short)
# Excluding utilizzo (too freq 1-gram)
# Excluding criteri (too freq 1-gram)
# Excluding azioni (too freq 1-gram)
# Adding Bundy
# Adding infants
# Excluding ’S EFFECTIVENESS (too short)
# Excluding KIT ’S (too short)
# Excluding maschi (too freq 1-gram)
# Adding behavior
# Adding these children
# Excluding rassegna (too freq 1-gram)
# Excluding W. (too short)
# Adding Sports
# Adding CHILDREN AGED
# Excluding differenza (too freq 1-gram)
# Adding cohort
# Excluding London (too freq 1-gram)
# Excluding attrezzi (too freq 1-gram)
# Adding handwriting
# Excluding AN OCCUPATIONAL (too short)
# Excluding standardizzazione (too freq 1-gram)
# Excluding traiettoria di sviluppo (too short)
# Excluding ON KIT (too short)
# Excluding dimensione (too freq 1-gram)
# Adding gruppo sperimentale
# Excluding mesi di allenamento (too short)
# Excluding ambiente (too freq 1-gram)
# Adding EFFECTIVENESS View
# Adding Educational
# Adding PRESCHOOL
# Excluding AMBIENTE$ (strange symbols)
# Excluding valutazioni (too freq 1-gram)
# Excluding Partecipazione (too freq 1-gram)
# Excluding Deficit (too freq 1-gram)
# Adding attività motorie
# Adding Keays
# Adding Infant
# Excluding scolas1ca (strange symbols)
# Adding rendimento scolastico
# Excluding corso (too freq 1-gram)
# Adding UNDERGOING LEUKEMIA
# Excluding strumenti (too freq 1-gram)
# Adding assessment
# Adding evoluzione favorevole
# Adding coordination disorder
# Adding stimolazione motoria quotidiana
# Excluding visione (too freq 1-gram)
# Excluding meta (too freq 1-gram)
# Adding QUFE insegnanti
# Excluding low birth (too short)
# Excluding personale (too freq 1-gram)
# Excluding pari (too freq 1-gram)
# Excluding Finanziamento (too freq 1-gram)
# Adding sintomatologia depressiva
# Excluding ripartizione (too freq 1-gram)
# Excluding /$L’ (strange symbols)
# Excluding diagnosi (too freq 1-gram)
# Adding progeFo
# Excluding esordio (too freq 1-gram)
# Excluding stallo (too freq 1-gram)
# Excluding  ­‐ (too short)
# Excluding Kaiser (too freq 1-gram)
# Excluding conto (too freq 1-gram)
# Adding PILOT STUDY
# Excluding Arts (too freq 1-gram)
# Excluding Obbiettivi (too freq 1-gram)
# Excluding difficoltà in ambito (too short)
# Excluding bambini con limitazioni (too short)
# Excluding CEP (too short)
# Excluding grado (too freq 1-gram)
# Excluding bambini con DCD (too short)
# Excluding fenomeno (too freq 1-gram)
# Adding Occupational Therapy
# Excluding dato (too freq 1-gram)
# Excluding development (too freq 1-gram)
# Adding tendenza significativa
# Excluding lezione (too freq 1-gram)
# Adding apprendimento scolastico
# Excluding Med Child (too short)
# Excluding Murray (too freq 1-gram)
# Adding progetto pilota
# Adding esame neurologico
# Adding comorbidità psicopatologica
# Adding Movement Assessment
# Excluding proposte (too freq 1-gram)
# Adding cluster
# Adding Pediatric Exercise
# Excluding Terapia (too freq 1-gram)
# Adding nascita pretermine
# Adding evidenze empiriche
# Adding childhood
# Excluding soggetti di controllo (too short)
# Excluding Cognitive (too freq 1-gram)
# Excluding minuti di attività (too short)
# Excluding costruNve$ (strange symbols)
# Excluding insegnamento (too freq 1-gram)
# Excluding Introduzione (too freq 1-gram)
# Adding attività motoria
# Adding terapia occupazionale
# Adding Iperattività
# Adding MedLine
# Adding Physical Education
# Excluding materiale (too freq 1-gram)
# Adding outcomes
# Adding LEUKEMIA TREATMENTS
# Excluding organizzazione in classe (too short)
# Adding FOSTER FINE
# Excluding Eur (too short)
# Excluding flessione (too freq 1-gram)
# Adding therapy
# Adding born
# Adding dysfunction
# Adding abilità grafo
# Excluding gesti (too freq 1-gram)
# Adding OCCUPATIONAL THERAPY
# Adding categorie iniziativa
# Excluding lavagna (too freq 1-gram)
# Adding Nicola Rudelli
# Adding behaviours
# Excluding questionario (too freq 1-gram)
# Excluding condizione (too freq 1-gram)
# Excluding Disturbi (too freq 1-gram)
# Excluding age (too short)
# Adding popolazione clinica
# Adding ambito motorio
# Excluding scolas1ci (strange symbols)
# Excluding St (too short)
# Excluding anno scolastico (too freq 2-gram)
# Excluding Research (too freq 1-gram)
# Adding including
# Adding Case Smith
# Excluding Iniziativa (too freq 1-gram)
# Excluding emozioni (too freq 1-gram)
# Excluding spostamenti (too freq 1-gram)
# Adding efﬁcacia
# Excluding Philadelphia (too freq 1-gram)
# Excluding low birth weight (too short)
# Excluding posizione (too freq 1-gram)
# Excluding totale (too freq 1-gram)
# Adding Weintraub
# Excluding aree (too freq 1-gram)
# Adding Inklusion
# Excluding rilevanza (too freq 1-gram)
# Adding preterm infants
# Adding oppositività
# Excluding der (too short)
# Excluding ecc. (strange symbols)
# Excluding integra1vo (strange symbols)
# Adding dimensione evolutiva
# Adding PROGETTO PILOTA
# Excluding Dewey (too freq 1-gram)
# Adding abilità sociali
# Excluding pilota di Monte (too short)
# Excluding Lido (too freq 1-gram)
# Excluding persistente (too freq 1-gram)
# Adding Victoria Infant
# Excluding disturbo di coordinazione (too short)
# Adding database elettronici
# Adding evidenze scientifiche
# Excluding Valore (too freq 1-gram)
# Excluding Legge (too freq 1-gram)
# Excluding disagio (too freq 1-gram)
# Adding Allegrante
# Excluding Acuità$visiva$ (strange symbols)
# Excluding gruppi (too freq 1-gram)
# Excluding lingua (too freq 1-gram)
# Adding bambini sani
# Adding Buck
# Adding fitness
# Adding Trudeau
# Excluding A5enzione$ (strange symbols)
# Adding SPSS
# Excluding tasso (too freq 1-gram)
# Excluding team di progeFo (too short)
# Excluding VMI (too short)
# Adding Poster
# Excluding norma (too freq 1-gram)
# Excluding Law M. (too short)
# Adding grafomotricità
# Adding Buktenica
# Excluding vista (too freq 1-gram)
# Adding Ziviani
# Adding eziopatogenesi
# Excluding sviluppo di disturbi (too short)
# Adding matter
# Excluding p. (too short)
# Adding programma scolastico
# Adding Cognitive Orientation
# Excluding Processi (too freq 1-gram)
# Excluding Ambiente (too freq 1-gram)
# Excluding Miller (too freq 1-gram)
# Adding Psychiatric
# Adding QUFE Insegnanti
# Excluding risposte (too freq 1-gram)
# Adding ergoterapiste
# Excluding Review (too freq 1-gram)
# Adding Child Development
# Excluding Vio (too short)
# Adding American Journal
# Excluding Santangelo (too freq 1-gram)
# Adding Motricità fine
# Excluding $ OUTPUT$ (too short)
# Excluding Cantone (too freq 1-gram)
# Adding popolazione specifica
# Excluding Eur Child (too short)
# Excluding Castelli (too freq 1-gram)
# Excluding Apprendimento (too freq 1-gram)
# Excluding marzo (too freq 1-gram)
# Adding preadolescent
# Excluding van (too short)
# Adding funzionamento cognitivo
# Excluding riferimento (too freq 1-gram)
# Excluding Bibliografia (too freq 1-gram)
# Adding Twin
# Adding Leitch
# Excluding fasce (too freq 1-gram)
# Adding studio esplorativo
# Excluding Velocità di scrittura (too short)
# Adding criteri diagnostici
# Excluding insegnanti in modo (too short)
# Excluding Velocità (too freq 1-gram)
# Adding reading
# Excluding presenza di depressione (too short)
# Adding endofenotipo
# Excluding Medicine (too freq 1-gram)
# Excluding SIMULTANEO (too freq 1-gram)
# Adding funzionamento sociale
# Excluding precoce (too freq 1-gram)
# Excluding Tempo (too freq 1-gram)
# Excluding autonomie (too freq 1-gram)
# Adding Ment
# Excluding approcci (too freq 1-gram)
# Adding risultati simili
# Adding Rosengard
# Excluding diminuzione (too freq 1-gram)
# Adding soggetti nati
# Excluding strategie (too freq 1-gram)
# Adding Child Adolesc
# Adding Questionnaire
# Adding schizophrenia
# Excluding benessere (too freq 1-gram)
# Excluding Marshall (too freq 1-gram)
# Excluding materie (too freq 1-gram)
# Adding Academic Achievement
# Adding Lazarus
# Excluding possibilità (too freq 1-gram)
# Excluding lezione di ginnastica (too short)
# Adding functions
# Excluding Revue (too freq 1-gram)
# Adding clinical
# Excluding prestazioni in compiti (too short)
# Adding risultati accademici
# Adding perinatal
# Excluding einem (too freq 1-gram)
# Excluding partecipanti (too freq 1-gram)
# Excluding Approccio$ (strange symbols)
# Excluding articolo (too freq 1-gram)
# Excluding team (too freq 1-gram)
# Excluding conseguenza (too freq 1-gram)
# Adding categorie seguenti
# Excluding World (too freq 1-gram)
# Excluding Percezione$ (strange symbols)
# Adding programma statistico
# Excluding bambini in età (too short)
# Excluding DA (too short)
# Excluding studi su bambini (too short)
# Excluding tappe (too freq 1-gram)
# Excluding Presentation · (too short)
# Excluding Gioia (too freq 1-gram)
# Excluding NC (too short)
# Adding impaccio motorio
# Adding Kolody
# Adding Livia Taverna
# Excluding sintomi di inattenzione (too short)
# Adding Doudin
# Adding monozigoti
# Excluding Morin (too freq 1-gram)
# Adding numero ridotto
# Adding Albaret
# Excluding ruolo (too freq 1-gram)
# Excluding Disabili1es (strange symbols)
# Excluding incidenza (too freq 1-gram)
# Excluding DSM IV TR (too short)
# Excluding compiti di motricità (too short)
# Excluding contesti di vita (too short)
# Excluding punto di vista (too short)
# Adding oculo
# Adding categorie motricità fine
# Adding Blizzard
# Adding born preterm
# Adding psychopathology
# Excluding Persona (too freq 1-gram)
# Adding primary
# Adding attività fisica quotidiana
# Excluding MOVIMENTO (too freq 1-gram)
# Excluding education (too freq 1-gram)
# Excluding educazione fisica (too freq 2-gram)
# Adding Sigfusdottir
# Adding relazione positiva
# Adding Hogrefe Editore
# Excluding pacchetto (too freq 1-gram)
# Excluding famiglia (too freq 1-gram)
# Excluding momenti (too freq 1-gram)
# Adding terapista
# Excluding UK (too short)
# Adding Reilly
# Adding Echsel
# Adding inattention
# Adding PROCESSING
# Excluding efficacia (too freq 1-gram)
# Adding categoria attenzione
# Excluding Superiore (too freq 1-gram)
# Adding successo scolastico
# Adding McKenzie
# Excluding Parole (too freq 1-gram)
# Excluding à (too short)
# Excluding Green (too freq 1-gram)
# Excluding prospettiva (too freq 1-gram)
# Adding base probabilistica
# Excluding processo (too freq 1-gram)
# Excluding riga (too freq 1-gram)
# Excluding BRIEF 2 (too short)
# Adding attention
# Excluding ipotesi (too freq 1-gram)
# Adding Motor
# Excluding 2nd (too short)
# Excluding realizzazione (too freq 1-gram)
# Adding effetto positivo
# Adding Behinderung
# Adding Kristjansson
# Excluding Ripartizione (too freq 1-gram)
# Excluding Aree$di$ (strange symbols)
# Excluding età adolescenziale (too short)
# Excluding AI (too short)
# Adding traiettorie evolutive
# Excluding OCCUPAZIONE$ (strange symbols)
# Excluding Partecipazione$sociale$ (strange symbols)
# Excluding stabilità (too freq 1-gram)
# Excluding lavori (too freq 1-gram)
# Excluding quo1dianità scolas1ca (strange symbols)
# Adding funzioni deficitarie
# Adding ﬁnanziamento
# Adding rating inventory
# Adding impulsività
# Excluding Hay (too short)
# Adding popolazione generale
# Adding Terapia occupazionale
# Adding Coonan
# Adding Camaiore
# Excluding were (too freq 1-gram)
# Excluding June (too freq 1-gram)
# Excluding Davis MN (too short)
# Adding Southern Switzerland
# Adding Cornoldi
# Adding ADHD
# Excluding cause (too freq 1-gram)
# Adding Integration
# Adding Adolesc Psychiatry
# Excluding salute (too freq 1-gram)
# Excluding processi (too freq 1-gram)
# Adding Sylvie
# Adding fibre interemisferiche
# Adding Sudgen
# Adding Worsley
# Adding prestazioni motorie
# Adding Corpo Calloso
# Adding sviluppo maggiore
# Excluding espressività (too freq 1-gram)
# Excluding Valutazione (too freq 1-gram)
# Adding AOTA Press
# Adding adjustment
# Excluding USA (too short)
# Adding Behavior
# Excluding ginnastica (too freq 1-gram)
# Excluding note (too freq 1-gram)
# Excluding lettura (too freq 1-gram)
# Excluding informazioni (too freq 1-gram)
# Adding Dollman
# Excluding studente (too freq 1-gram)
# Excluding rischio di problemi (too short)
# Excluding disabilità (too freq 1-gram)
# Adding cohort study
# Adding Angelika
# Excluding Gentile (too freq 1-gram)
# Adding Community
# Excluding Social (too freq 1-gram)
# Excluding trattamento (too freq 1-gram)
# Adding scuola regolare svizzera
# Excluding chiave (too freq 1-gram)
# Adding Neurological
# Adding Equilibrio Palla
# Adding programma proposto
# Adding adolescence
# Excluding sistema scolas1co integra1vo (strange symbols)
# Excluding capacità (too freq 1-gram)
# Excluding Rivista (too freq 1-gram)
# Excluding Emilia (too freq 1-gram)
# Excluding impatto (too freq 1-gram)
# Excluding tempo (too freq 1-gram)
# Excluding tono (too freq 1-gram)
# Excluding self  (too short)
# Excluding ambiti (too freq 1-gram)
# Excluding occupazioni (too freq 1-gram)
# Excluding MM (too short)
# Adding Study Group
# Adding Barnett
# Adding Questionario Funzioni
# Excluding momento (too freq 1-gram)
# Adding Schools
# Excluding programma di stimolazione (too short)
# Adding MOFIS
# Adding Montréal
# Excluding impegno (too freq 1-gram)
# Adding Activity
# Adding Welsh
# Excluding LU (too short)
# Adding Sibley
# Adding MABC
# Excluding atto (too freq 1-gram)
# Excluding Tendenza (too freq 1-gram)
# Adding Sannio Fancello
# Excluding Doyle LW (too short)
# Excluding via di standardizzazione (too short)
# Excluding attività di motricità (too short)
# Excluding status (too freq 1-gram)
# Excluding Incremento (too freq 1-gram)
# Excluding esercizio (too freq 1-gram)
# Excluding disabili (too freq 1-gram)
# Excluding handicap (too freq 1-gram)
# Excluding comprensione (too freq 1-gram)
# Excluding rapporto (too freq 1-gram)
# Adding Tomporowski
# Excluding Van (too short)
# Excluding programmi (too freq 1-gram)
# Adding comorbilità
# Excluding contesto (too freq 1-gram)
# Excluding Prassie$visuo/ costruNve$ (strange symbols)
# Adding specially
# Excluding regresso (too freq 1-gram)
# Excluding soft (too freq 1-gram)
# Excluding progetti (too freq 1-gram)
# Excluding Principi (too freq 1-gram)
# Excluding Inclusione (too freq 1-gram)
# Adding Kaelin
# Excluding origine (too freq 1-gram)
# Excluding Dean (too freq 1-gram)
# Excluding change (too freq 1-gram)
# Adding CCBESS
# Excluding incarichi (too freq 1-gram)
# Excluding compiti di coordinazione (too short)
# Adding SEQUENZIALE
# Adding paralisi cerebrale
# Excluding Association (too freq 1-gram)
# Adding Psychological Corporation
# Adding condizione medica
# Adding Centrati
# Adding programma motorio specifico
# Excluding Vera (too freq 1-gram)
# Excluding cammino (too freq 1-gram)
# Adding Baird
# Excluding States (too freq 1-gram)
# Adding bambini nati
# Adding assessor
# Adding adolescent
# Excluding J Pediatr (too short)
# Adding attività proposte
# Adding adolescents
# Adding disturbi psichiatrici
# Excluding coorte (too freq 1-gram)
# Excluding Questionario in via (too short)
# Excluding comportamento in classe (too short)
# Adding compiti scolastici
# Excluding UOC Neurologia (too short)
# Excluding problemi di inattenzione (too short)
# Adding punteggio massimo
# Excluding giochi (too freq 1-gram)
# Excluding cogni8va$ (strange symbols)
# Adding Graw Hill
# Adding disturbi internalizzanti
# Excluding role (too freq 1-gram)
# Excluding bambini con difficoltà (too short)
# Adding effects
# Excluding Caratteri (too freq 1-gram)
# Excluding Lewis (too freq 1-gram)
# Adding risultati preliminari
# Adding FUNZIONI ESECUTIVE
# Excluding Occupa1ons (strange symbols)
# Excluding Risultati (too freq 1-gram)
# Excluding processi di apprendimento (too short)
# Adding signs
# Adding PsychInfo
# Adding Barkley
# Adding Alamargot
# Adding CARASSO
# Adding comportamenti iperattivi
# Excluding Ipotesi (too freq 1-gram)
# Excluding Ordine (too freq 1-gram)
# Adding Ministère
# Excluding supporto (too freq 1-gram)
# Excluding serie (too freq 1-gram)
# Excluding versione italiana (too freq 2-gram)
# Excluding Dyck MJ (too short)
# Adding Ospedale Versilia
# Excluding Wilson (too freq 1-gram)
# Adding Dodd
# Adding giornata scolastica
# Excluding passo (too freq 1-gram)
# Adding Isquith
# Adding progeP
# Adding Boshoff
# Excluding ∆ in numero (too short)
# Adding evidenza scientifica
# Adding functioning
# Excluding Res (too short)
# Adding Article
# Adding Studi longitudinali
# Excluding $ /$L’ (too short)
# Excluding Rev (too short)
# Adding Quelles
# Excluding language (too freq 1-gram)
# Adding examination
# Adding Molfese
# Adding extremely
# Excluding problemi di tipo (too short)
# Excluding Bara (too freq 1-gram)
# Adding categorie controllo emotivo
# Adding Gathercole
# Adding Occupational Performance
# Excluding quotidiani (too freq 1-gram)
# Adding anxiety
# Excluding fascia (too freq 1-gram)
# Adding emerging
# Adding Everyday
# Excluding MONTE (too freq 1-gram)
# Excluding Reggio (too freq 1-gram)
# Excluding Giunti O. (too short)
# Excluding INPUT $ (too short)
# Adding Movement assessment
# Excluding • (too short)
# Adding McCarthy
# Excluding Discussione (too freq 1-gram)
# Excluding who (too short)
# Adding valutazione finale
# Excluding disturbi d’ ansia (too short)
# Excluding Occupazione (too freq 1-gram)
# Adding Mental
# Adding Naglieri
# Adding quality
# Adding motor integration
# Excluding old children (too short)
# Adding Allison
# Excluding BSc$Occupa8onal$Therapy$ Centro$Ergoterapia$Pediatrica,$Bellinzona$ (strange symbols)
# Adding espressività psicopatologica
# Adding Article CITATIONS
# Adding retest
# Excluding Baird G (too short)
# Excluding uso (too short)
# Adding Occu Shep
# Excluding Van Braeckel (too short)
# Adding problemi comportamentali seri
# Excluding progressione (too freq 1-gram)
# Adding sanitarie importanti
# Excluding classe di allievi (too short)
# Excluding Rigoli D (too short)
# Adding livello fisico
# Adding patologie psichiatriche
# Adding regional cohort
# Adding Hillman
# Excluding modalità di insegnamento (too short)
# Adding Neuropsicologia
# Excluding calo (too freq 1-gram)
# Adding Etnier
# Excluding birth in relation (too short)
# Adding Unità Sanitaria Locale
# Adding competenza sociale
# Excluding  ­‐ Understanding (too short)
# Adding esempio paralisi cerebrale
# Adding Educational Psychological
# Excluding corrispondenza (too freq 1-gram)
# Adding graphomotricité
# Adding Developmental variations
# Excluding Hay DA (too short)
# Adding modo rapido
# Excluding für Deutschland (too short)
# Adding condizione medica generale
# Excluding persistenza (too freq 1-gram)
# Excluding partenariato con docenti (too short)
# Adding attitudine positiva
# Adding sostanza bianca cerebrale
# Excluding Approccio$ bo5om/ (strange symbols)
# Adding Strengths
# Excluding BMI (too short)
# Excluding vita quo0diana (strange symbols)
# Excluding /an8saccadi$ /compi8$go (strange symbols)
# Excluding sviluppo di complicanze (too short)
# Adding Educational Accessibility
# Excluding dicembre (too freq 1-gram)
# Excluding età adulta (too short)
# Excluding Cura$di$sé:$rou8nes$ ProduNvità:$scuola,$lavoro$ (strange symbols)
# Excluding puzzle (too freq 1-gram)
# Adding Learning
# Excluding Ergoterapia$e$ADHD$ BAMBINO (strange symbols)
# Adding were born
# Excluding SDQ (too short)
# Excluding · (too short)
# Adding effetti secondari
# Adding Sibling Questionnaire
# Excluding indicatore (too freq 1-gram)
# Adding flessione significativa
# Adding bambini eccezionali
# Adding espressività clinica
# Excluding Accademia (too freq 1-gram)
# Excluding Van Donkelaar (too short)
# Excluding Generalizzato (too freq 1-gram)
# Excluding difficoltà di riconoscimento (too short)
# Excluding ruota (too freq 1-gram)
# Excluding Neuropsich Età (too short)
# Adding lavori manuali
# Adding PROFILE Lietta
# Adding posizione seduta
# Adding Leblanc
# Adding June Trude
# Excluding alternanza$lontano/ vicino$(Ri5y$et$al (strange symbols)
# Excluding und Behinderung (too short)
# Adding scuole regolari
# Adding fenotipo cognitivo
# Excluding Accomodazione:$ /$Se$5t$medicamentoso$ (strange symbols)
# Adding Pyschiatric Association
# Adding Psychiatr Scand
# Excluding livello di sintomatologia (too short)
# Excluding bambini con ritardo (too short)
# Excluding Coordina1on (strange symbols)
# Adding Kenworthy
# Adding McMaster University
# Excluding TRATTA$ ADATTA$ (strange symbols)
# Adding numeracy
# Excluding hat sich (too short)
# Excluding Narberhaus A (too short)
# Adding regular moderate
# Adding Woollacott
# Excluding BOT (too short)
# Adding school aged children
# Excluding qualità di vita (too short)
# Adding Generalversammlung
# Excluding 2Risultati (strange symbols)
# Adding distrofie
# Excluding RG.2.1.4010.2163 CITATIONS (strange symbols)
# Adding Kaelin University
# Adding relation
# Excluding Mc Hale (too short)
# Adding esercizi quotidiani
# Adding Pediatrics Activity
# Excluding un$amico.$$ SIMULTANEO (strange symbols)
# Adding Disturbo Oppositivo
# Adding evoluzione superiore
# Excluding MR (too short)
# Excluding consegna (too freq 1-gram)
# Adding studio longitudinale
# Adding January
# Excluding Petrenchik T. (too short)
# Adding disturbo specifico
# Excluding Twin Res (too short)
# Excluding differenza di genere (too short)
# Adding Quelles acquisitions
# Excluding S. E. (too short)
# Adding accadimento
# Excluding RG.2.1.3789.8002 CITATIONS (strange symbols)
# Adding autoconsapevolezza
# Excluding lavora1vi (strange symbols)
# Adding classification
# Excluding memorizzazione (too freq 1-gram)
# Excluding svantaggi (too freq 1-gram)
# Excluding età giovane adulta (too short)
# Excluding ironia (too freq 1-gram)
# Excluding abilità di scrittura (too short)
# Adding achievements
# Excluding S. Gioia (too short)
# Excluding bambini con handicap (too short)
# Excluding cervello (too freq 1-gram)
# Excluding application to social (too short)
# Adding programma scolastico regolare
# Adding pilot study
# Excluding Psychol Med (too short)
# Excluding cluster di segni (too short)
# Excluding Nuova Zelanda (too freq 2-gram)
# Excluding Federa1on (strange symbols)
# Excluding Hallmayer J. (too short)
# Excluding Nazioni Unite (too freq 2-gram)
# Excluding Posturale,$sensoriale,$visiva,$cogni8va$ (strange symbols)
# Adding Borkowski
# Excluding obbiettivi (too freq 1-gram)
# Excluding gemelli (too freq 1-gram)
# Adding Saavedra
# Excluding gioco (too freq 1-gram)
# Adding comportamenti impulsivi
# Excluding children who were (too short)
# Excluding Grazie$per$l’ (strange symbols)
# Adding approfondimenti interessanti
# Excluding energia (too freq 1-gram)
# Excluding conferma (too freq 1-gram)
# Excluding calma (too freq 1-gram)
# Excluding volti (too freq 1-gram)
# Adding Motoria Disturbi
# Adding PsycInfo
# Excluding ADHD$e$disturbi$visuo (strange symbols)
# Adding Biblio Barkle
# Adding tracking
# Adding disfunzione esecutiva
# Excluding corpus (too freq 1-gram)
# Excluding creatività (too freq 1-gram)
# Excluding acquisizione di abilità (too short)
# Excluding gemello (too freq 1-gram)
# Excluding Percorso (too freq 1-gram)
# Excluding Cornoldi C. (too short)
# Excluding Anand KJS (too short)
# Adding Parole chiave
# Adding Beey Buktenica
# Excluding associazione (too freq 1-gram)
# Excluding Fombonne E. (too short)
# Excluding Nomura Y (too short)
# Adding States childhood
# Excluding eliminazione di svantaggi (too short)
# Excluding Ahonen TP (too short)
# Excluding decennio (too freq 1-gram)
# Excluding Disorder at (too short)
# Excluding Sintesi (too freq 1-gram)
# Excluding investimento (too freq 1-gram)
# Adding prestazioni occupazionali
# Adding Falsa Credenza
# Adding Anerkennung
# Excluding Dedrich M. (too short)
# Excluding Flessibilità$cogni8va,$ (strange symbols)
# Excluding idee di giochi (too short)
# Excluding progressi (too freq 1-gram)
# Excluding Wilson BN (too short)
# Excluding Pulirsi WC (too short)
# Excluding present a delay (too short)
# Adding dibattito teorico
# Adding Childhood
# Excluding Bennett KS (too short)
# Adding Daigneault
# Excluding richiesta (too freq 1-gram)
# Excluding Smyth MM (too short)
# Excluding J Psychiatry (too short)
# Excluding For Children (too short)
# Excluding /$Coaching$ai$docen8$e$ai$ (strange symbols)
# Excluding ricreazione (too freq 1-gram)
# Adding Behavioral Nutrition
# Excluding misura (too freq 1-gram)
# Excluding function in healthy (too short)
# Adding disfunzioni motorie
# Excluding Missiuna C. (too short)
# Excluding Braeckel KN (too short)
# Adding Mode Outco
# Adding infancy
# Excluding Ham J (too short)
# Adding risu
# Adding Task Training
# Excluding idee (too freq 1-gram)
# Adding scrittura manuale compromessa
# Adding Body Mass
# Adding Prochaska
# Excluding San1nelli LieFa (strange symbols)
# Excluding difficoltà di sviluppo (too short)
# Adding percorso casa
# Excluding behavior in children (too short)
# Excluding Età Evol (too short)
# Excluding Hadley T (too short)
# Excluding figlio (too freq 1-gram)
# Adding oscilli
# Adding casascuola
# Excluding Toscana (too freq 1-gram)
# Adding Shallice
# Excluding Controllo$oculomotorio $ (too short)
# Excluding distribuzione (too freq 1-gram)
# Excluding emo8vo,$impulsività$ Aree$di$ (strange symbols)
# Adding modifiche ambientali
# Excluding 6Valutazione scolastica (strange symbols)
# Adding compiti quotidiani
# Adding adolescent twins
# Excluding Dewey D (too short)
# Adding Relationships between
# Excluding scolas1co à (too short)
# Adding DCDQ
# Excluding programmi di stimolazione (too short)
# Adding Ment Retard
# Excluding Ministero (too freq 1-gram)
# Excluding umore (too freq 1-gram)
# Excluding trave (too freq 1-gram)
# Adding damage
# Excluding Pollock N. (too short)
# Excluding ﬂessibilità$cogni8va,$controllo$ (strange symbols)
# Adding children that suffered
# Excluding stimolazioni di educazione (too short)
# Adding manifestazioni comportamentali
# Adding Cana Schill
# Adding motor coordination
# Excluding immaginazione (too freq 1-gram)
# Excluding gesti in modo (too short)
# Adding school' based
# Adding preadolescenti
# Adding SUPSI
# Excluding Rabinowitz J (too short)
# Excluding causa di ripercussioni (too short)
# Excluding Lehrbeispiel für (too short)
# Excluding ﬁltraggio$degli$s8moli)$ /$Oculomotricità$e$strategie$ (strange symbols)
# Adding modalità relazionale
# Excluding bugie (too freq 1-gram)
# Adding Innovative Practices
# Excluding Conclusioni (too freq 1-gram)
# Excluding Lyon (too freq 1-gram)
# Excluding schizofrenia in età (too short)
# Excluding /SCUOLA$ /TEMPO$LIBERO$ (strange symbols)
# Excluding l‘inclusione (strange symbols)
# Excluding Sugden DA (too short)
# Excluding giorno di intensità (too short)
# Adding Polatajko
# Excluding Parma (too freq 1-gram)
# Excluding obbiettivo (too freq 1-gram)
# Adding programma scolastico normale
# Adding sﬁda
# Excluding Rouse J (too short)
# Excluding approcci d' inclusione (too short)
# Adding Phyisical Activity
# Adding internalizing
# Excluding Movimento (too freq 1-gram)
# Excluding Per$svolgere$ques8$compi8$il$bambino$ (strange symbols)
# Adding motivazion
# Excluding Pordenone (too freq 1-gram)
# Adding prospects from
# Excluding strategie di intervento (too short)
# Adding forma fisica
# Adding Perinatal
# Adding along development
# Excluding UK population (too short)
# Adding caratteristiche neuroevolutive
# Adding disease risk
# Adding compiti motori
# Adding scrittura leggibile
# Excluding volta (too freq 1-gram)
# Excluding Caldù X (too short)
# Excluding inclusione (too freq 1-gram)
# Adding decrease
# Adding ﬂessibilità zazione
# Excluding attività di memorizzazione (too short)
# Excluding plus (too freq 1-gram)
# Excluding casi (too freq 1-gram)
# Excluding incidenza di disagio (too short)
# Adding veriﬁ
# Excluding feedback (too freq 1-gram)
# Adding Health Education
# Adding Empir Journ
# Excluding Obiettivi (too freq 1-gram)
# Excluding Haming M (too short)
# Adding parte pedagogico didattica
# Adding sintomi ansiosi
# Adding partenariato
# Excluding Gasperoni TL (too short)
# Excluding TO Svizzeri (too short)
# Excluding velocità di risposta (too short)
# Excluding conoscenze (too freq 1-gram)
# Excluding costruNve$ /$Funzioni$esecu8ve$ (strange symbols)
# Adding einem outside
# Adding impulsivity
# Excluding intervento con bambini (too short)
# Adding unaffected siblings
# Adding disfunzione neurologica minore
# Adding Minor Neurological
# Excluding gomma (too freq 1-gram)
# Adding sviluppo cerebrale
# Adding Lawrence Erlbaum
# Excluding M. F. (too short)
# Adding Interaction
# Adding Disorder Externalizing
# Excluding Enabling Par1cipa1on (strange symbols)
# Excluding self  worth (too short)
# Adding Sports Sciences
# Adding scuola superiore
# Excluding Can’ (strange symbols)
# Excluding misure necessarie (too freq 2-gram)
# Adding Funzioni EsecutiveGenitori
# Excluding Aspetti (too freq 1-gram)
# Adding complicated
# Adding abilità gestuali
# Adding Echsel Angelika
# Excluding Aurelia (too freq 1-gram)
# Adding Schilling
# Adding Lausanne
# Excluding Ricreazione (too freq 1-gram)
# Adding fattore importante
# Excluding Laura$Rodesino$ BSc$Occupa8onal$Therapy$ (strange symbols)
# Excluding Sci 2008;27:668 (too short)
# Excluding all‘interno (strange symbols)
# Adding goniometro
# Excluding attenzione in classe (too short)
# Excluding https://www.researchgate.net/publication/295351415 Ergoterapia (strange symbols)
# Excluding fasce di età (too short)
# Adding Petrig
# Excluding Paesi (too freq 1-gram)
# Excluding compiti di riconoscimento (too short)
# Excluding Green D (too short)
# Adding neuroimmagini
# Adding Acta Psychiatr
# Adding Keays Mode
# Adding Difficulties Questionnaire
# Adding cause diverse
# Excluding ricorso (too freq 1-gram)
# Excluding Teoria (too freq 1-gram)
# Excluding partenza (too freq 1-gram)
# Adding classe controllo
# Excluding riduzione (too freq 1-gram)
# Adding Statistical Manual
# Excluding They’ (strange symbols)
# Adding Vera Kaelin
# Adding shifting
# Excluding Engeland H. (too short)
# Adding coordinazione oculo
# Adding Thera Occu
# Excluding compito di cognizione (too short)
# Excluding Compiti di comprensione (too short)
# Adding sistema propriocettivo
# Excluding more (too freq 1-gram)
# Adding Jensen
# Adding themes
# Adding Baltimore
# Adding Krasnegor
# Excluding perceived self  (too short)
# Adding Dexter
# Excluding from a review (too short)
# Adding resistance
# Excluding opinione (too freq 1-gram)
# Excluding attività di coordinazione (too short)
# Excluding related to motor (too short)
# Excluding Vestirsi (too freq 1-gram)
# Excluding N=9 (too short)
# Adding coronary
# Excluding Chan RC (too short)
# Adding aspetto sensibile
# Adding programscrittura
# Excluding età successiva (too short)
# Adding sport performance
# Excluding malattie (too freq 1-gram)
# Excluding 32(5 (strange symbols)
# Excluding durata (too freq 1-gram)
# Excluding RG.2.2.18708.76162 (strange symbols)
# Excluding specially in writing (too short)
# Excluding ordine$temporale.$ (strange symbols)
# Adding funzionamento cerebrale
# Excluding effects of regular (too short)
# Adding Attività fisica
# Excluding esterno (too freq 1-gram)
# Adding ambiti funzionali
# Excluding Ray ­‐Kaeser Sylvie (too short)
# Excluding Sigurdsson E. (too short)
# Adding between physical
# Excluding J Am (too short)
# Excluding Lavare (too freq 1-gram)
# Excluding stato (too freq 1-gram)
# Adding NOMI PRIMA
# Adding ergoterapici
# Excluding Lussier$F.,$Flessas$J.,$2009,$Neuropsychologie$de$l’ enfant.$Troubles$développementaux$et$de$l’ (strange symbols)
# Adding Baltim Caserapy
# Adding indicazioni ottimistiche
# Adding adolescent anxiety
# Adding perinatal problems
# Adding Tower
# Adding école
# Excluding /$Se$5t$medicamentoso$ Binocularità (strange symbols)
# Adding ambito clinico
# Adding Child Adol
# Adding preterm infants predicts
# Adding ergoterapista
# Excluding linea (too freq 1-gram)
# Excluding sezione (too freq 1-gram)
# Adding Everyday Life
# Excluding Hum Genet (too short)
# Excluding matematica (too freq 1-gram)
# Excluding acuità$visiva$normale,$ (strange symbols)
# Excluding Canada (too freq 1-gram)
# Adding Text Revision
# Excluding infanzia di capacità (too short)
# Adding Nerv Ment
# Excluding /$Stabilità$posturare$e$ (strange symbols)
# Excluding Di Camaiore (too short)
# Excluding condotta (too freq 1-gram)
# Excluding ProduNvità:$scuola,$lavoro$ Tempo$libero$ (strange symbols)
# Adding Svizzera italiana
# Excluding Res Rev (too short)
# Excluding obiettivi (too freq 1-gram)
# Adding automatizzazione
# Adding heart
# Excluding At Risk Mental (too short)
# Adding Psychopathological comorbidity
# Adding Echsel Zurich
# Excluding inibizione$oculomotoria$ /an8saccadi$ (strange symbols)
# Excluding editor (too freq 1-gram)
# Excluding i.e (too short)
# Adding Motor coordination
# Adding disturbi affettivi
# Adding practice
# Excluding ottimisti sull’ esistenza (strange symbols)
# Adding studio epidemiologico
# Excluding legame tra movimento (too short)
# Excluding Giochi (too freq 1-gram)
# Adding prestazioni inferiori
# Adding strategia utile
# Excluding Hughes (too freq 1-gram)
# Excluding Keen J (too short)
# Excluding serie di compiti (too short)
# Adding Dexte know
# Excluding Hollister J (too short)
# Adding Definition
# Excluding mesi di stimolazione (too short)
# Adding competenza percepita
# Excluding velocità di elaborazione (too short)
# Adding Kaelin Vera
# Adding categoria pianiﬁcazione
# Adding caianiﬁcazione ibilità
# Excluding go$ Elaborazione$ (too short)
# Adding cognition
# Adding Specializzata View
# Adding Progress
# Adding ricerche recenti
# Adding prestazioni accademiche
# Adding Deitz
# Adding cognizione sociale
# Adding tono muscolare
# Excluding prognosi (too freq 1-gram)
# Adding literacy
# Excluding Tel (too short)
# Adding fascia rossa
# Excluding paradigma (too freq 1-gram)
# Excluding eliminazione (too freq 1-gram)
# Adding entschieden
# Adding Occupational therapy
# Excluding www.ergoterapiapediatrica.ch$ Lie5a$San8nelli,$Laura$Rodesino$2013,$ (strange symbols)
# Excluding Monahan KC (too short)
# Excluding OT (too short)
# Excluding invalidità (too freq 1-gram)
# Adding Tomp Child
# Excluding 8) (too short)
# Adding allenamento motorio speciﬁco
# Adding Mainardi University
# Excluding camicia (too freq 1-gram)
# Excluding 29° (too short)
# Adding abilità necessarie
# Excluding approccio (too freq 1-gram)
# Adding Corpus Callosum
# Adding distrofia muscolare
# Adding Child Behavior
# Adding percezione visiva
# Excluding Ziviani J. (too short)
# Adding Hillmann
# Excluding Johnson M. (too short)
# Adding Switzerland View
# Excluding dell‘uomo (strange symbols)
# Excluding interazione (too freq 1-gram)
# Adding particolare recenti
# Excluding trajectories of children (too short)
# Excluding POLETTI UOC (too short)
# Adding Poletti Azienda
# Adding momenti successivi
# Excluding appunti (too freq 1-gram)
# Excluding I. (too short)
# Excluding rischio di sviluppo (too short)
# Adding esordio psicotico
# Excluding cliente (too freq 1-gram)
# Excluding sottoposta (too freq 1-gram)
# Excluding deficit (too freq 1-gram)
# Adding Health behavior
# Adding categoria diagnostica
# Excluding https://www.researchgate.net/publication/333176072 MOFIS (strange symbols)
# Excluding importanza in relazione (too short)
# Excluding livello di rendimento (too short)
# Excluding Scientia (too freq 1-gram)
# Adding young adults
# Excluding modalità di applicazione (too short)
# Excluding stima (too freq 1-gram)
# Adding esternalizzanti Disturbi esternalizzanti
# Adding delay
# Adding Empirical
# Excluding Jantzen W. (too short)
# Excluding ’s Intelligence (too short)
# Adding vita Comorbidità psicopatologica
# Adding instruction
# Adding inhibition
# Adding candidate endophenotypes
# Excluding J Nerv (too short)
# Excluding inizio (too freq 1-gram)
# Adding test supplementari
# Excluding esperienza da parte (too short)
# Excluding compagno di classe (too short)
# Excluding giudizi (too freq 1-gram)
# Excluding RG.2.1.3396.5849 CITATIONS (strange symbols)
# Excluding Consiglio (too freq 1-gram)
# Excluding empatia (too freq 1-gram)
# Adding Fourth Edition
# Excluding classe di scuola (too short)
# Adding criteri diagnostici relativi
# Excluding raccomandazioni (too freq 1-gram)
# ...
# preadolescenti Language.SPANISH
# SUPSI Language.GERMAN
# modalità relazionale Language.ITALIAN
# Innovative Practices Language.ENGLISH
# forma fisica Language.ITALIAN
# caratteristiche neuroevolutive Language.ITALIAN
# compiti motori Language.ITALIAN
# scrittura leggibile Language.ITALIAN
# decrease Language.ENGLISH
# veriﬁ Language.SPANISH
# parte pedagogico didattica Language.ITALIAN
# sintomi ansiosi Language.ITALIAN
# unaffected siblings Language.ENGLISH
# Minor Neurological Language.ENGLISH
# sviluppo cerebrale Language.ITALIAN
# complicated Language.ENGLISH
# abilità gestuali Language.ITALIAN
# fattore importante Language.ITALIAN
# goniometro Language.ITALIAN
# neuroimmagini Language.ITALIAN
# cause diverse Language.ENGLISH
# classe controllo Language.ITALIAN
# coordinazione oculo Language.ITALIAN
# sistema propriocettivo Language.ITALIAN
# themes Language.ENGLISH
# resistance Language.ENGLISH
# aspetto sensibile Language.ITALIAN
# programscrittura Language.ITALIAN
# sport performance Language.ENGLISH
# funzionamento cerebrale Language.ITALIAN
# ambiti funzionali Language.ITALIAN
# ergoterapici Language.SPANISH
# indicazioni ottimistiche Language.ITALIAN
# ambito clinico Language.ITALIAN
# Child Adol Language.ENGLISH
# preterm infants predicts Language.ENGLISH
# ergoterapista Language.ITALIAN
# heart Language.ENGLISH
# disturbi affettivi Language.ITALIAN
# practice Language.ENGLISH
# studio epidemiologico Language.ITALIAN
# prestazioni inferiori Language.ITALIAN
# strategia utile Language.ITALIAN
# Definition Language.ENGLISH
# caianiﬁcazione ibilità Language.ITALIAN
# ricerche recenti Language.ITALIAN
# prestazioni accademiche Language.ITALIAN
# tono muscolare Language.ITALIAN
# fascia rossa Language.ITALIAN
# entschieden Language.GERMAN
# allenamento motorio speciﬁco Language.SPANISH
# Mainardi University Language.ENGLISH
# abilità necessarie Language.ITALIAN
# distrofia muscolare Language.ITALIAN
# particolare recenti Language.ITALIAN
# momenti successivi Language.ITALIAN
# esordio psicotico Language.ITALIAN
# categoria diagnostica Language.ITALIAN
# esternalizzanti Disturbi esternalizzanti Language.ITALIAN
# delay Language.ENGLISH
# instruction Language.FRENCH
# candidate endophenotypes Language.ENGLISH
# test supplementari Language.ITALIAN
# criteri diagnostici relativi Language.SPANISH
# disturbo motorio Language.ITALIAN
# sviluppo cognitivo Language.ITALIAN
# richieste scolastiche future Language.ITALIAN
# corpo quale supporto Language.ITALIAN
# beneﬁ Language.SPANISH
# Bibliograﬁ Language.SPANISH
# termini statistici Language.ITALIAN
# disabilità ﬁsiche Language.ITALIAN
# evoluzione significativa Language.ITALIAN
# Disturbi emotivi Language.ITALIAN
# abilità fini Language.ITALIAN
# Health Organization Language.ENGLISH
# ruoli sociali Language.ITALIAN
# Pressley Language.ENGLISH
# fattore premonitore significativo Language.ITALIAN
# paralisi cerebrale infantile Language.SPANISH
# attività quotidiane Language.ITALIAN
# funzioCl Language.ITALIAN
# DiriH Language.ITALIAN
# Socioeconomico Language.ITALIAN
# knowledge Language.ENGLISH
# stimolazioni Language.ITALIAN
# Integrazione' sensoriale' Language.ITALIAN
# relazione significativa Language.ITALIAN
# livello psicosociale Language.ITALIAN
# Bruininks Language.ENGLISH
# disgrafia Language.ITALIAN
# disturbi ansiosi Language.ITALIAN
# esperienza scolastica Language.ITALIAN
# materie scolastiche Language.ITALIAN
# discinesie coreiformi Language.ITALIAN
# classi regolari Language.ITALIAN
# factors Language.ENGLISH
# hyperactivity Language.ENGLISH
# validazione Language.ITALIAN
# disfunzione percettomotoria Language.ITALIAN
# utilizzo comune Language.ITALIAN
# identifies Language.ENGLISH
# inten Language.GERMAN
# studi recenti Language.ITALIAN
# stabilità posturale Language.ITALIAN
# dysfunctions Language.ENGLISH
# soggetto strategico Language.ITALIAN
# Prevalence Language.ENGLISH
# publiq Language.FRENCH
# disagio mentale Language.ITALIAN
# scotch Language.ENGLISH
# critical review Language.ENGLISH
# tipo esternalizzante Language.ITALIAN
# livello motorio Language.ITALIAN
# atipie pragmatiche Language.ITALIAN
# limiti riconosciuti Language.ITALIAN
# tendenza signiﬁcativa Language.ITALIAN
# vantaggio significativo Language.ITALIAN
# Delgado Language.SPANISH
# prerequisiti Language.ENGLISH
# attività speciﬁ Language.ITALIAN
# esercizio mirato Language.ITALIAN
# gruppo controllo Language.ITALIAN
# handwriting research Language.ENGLISH
# Canadian Occupational Language.ENGLISH
# ritardo marcato Language.ITALIAN
# autonomie personali Language.ITALIAN
# contesti specialistici Language.ITALIAN
# options Language.FRENCH
# scuola primaria Language.ITALIAN
# proposte teoriche Language.ITALIAN
# lezioni scolastiche Language.ITALIAN
# azioni motorie dirette Language.ITALIAN
# motor performance Language.ENGLISH
# condizione medica precisa Language.ITALIAN
# passo dopo passo Language.ITALIAN
# processazione Language.ITALIAN
# persistence Language.FRENCH
# ospedalizzazione Language.ITALIAN
# categoria pianificazione Language.ITALIAN
# tappe importanti Language.ITALIAN
# campione totale Language.ITALIAN
# rilevanza clinica Language.ITALIAN
# peer influence Language.ENGLISH
# Memoria' Language.ITALIAN
# nascita inferiore Language.ITALIAN
# aspetto strumentale Language.ITALIAN
# livello atteso Language.ITALIAN
# livello accademico Language.ITALIAN
# prestazione occupazionale Language.ITALIAN
# general intellectual Language.ENGLISH
# tappe fondamentali Language.ITALIAN
# autonomie funzionali Language.ITALIAN
# caratteristiche cognitive Language.ITALIAN
# abilities Language.ENGLISH
# plasticità cerebrale Language.ITALIAN
# contesti scolastici ordinari Language.ITALIAN
# genitori attraverso questionari Language.ITALIAN
# sviluppo motorio persistenti Language.ITALIAN
# fibre mielinizzate Language.ITALIAN
# disturbi visuo Language.ITALIAN
# directly related Language.ENGLISH
# complicanze perinatali Language.ITALIAN
# visual Language.SPANISH
# differenza positiva Language.ITALIAN
# attività motoria quotidiana Language.ITALIAN
# disprassia evolutiva Language.ITALIAN
# movimento quotidiano Language.ITALIAN
# Attività necessarie Language.ITALIAN
# propriocezione Language.ITALIAN
# materie principali Language.ITALIAN
# années Language.FRENCH
# impairments Language.ENGLISH
# terapeutiche speciali Language.ITALIAN
# partecipazione sociale Language.ITALIAN
# terminologia diagnostica utilizzata Language.ITALIAN
# motricità oculare Language.ITALIAN
# scoperta guidata Language.ITALIAN
# followup Language.ENGLISH
# prospettiva evolutiva Language.ITALIAN
# motoria maggiore Language.ITALIAN
# Approccio' school' Language.ITALIAN
# attività sportive Language.ITALIAN
# traiettoria evolutiva Language.ITALIAN
# dimensione spazio Language.ITALIAN
# studies permit Language.GERMAN
# difficoltà cognitive Language.ITALIAN
# problemi perinatali Language.ITALIAN
# ipotesi iniziali Language.ITALIAN
# livello inferiore Language.ITALIAN
# majority Language.ENGLISH
# allerta Language.ITALIAN
# regioni frontali Language.ITALIAN
# materiali utilizzati Language.ITALIAN
# swedish national Language.ENGLISH
# studi riscontrano Language.ITALIAN
# memory Language.ENGLISH
# controllo cognitivo Language.ITALIAN
# databases Language.ENGLISH
# Funzioni EsecutiveInsegnanti Language.ITALIAN
# Geneva Language.ITALIAN
# mese seguente Language.ITALIAN
# prestazione scolastica Language.ITALIAN
# condizione clinica Language.ITALIAN
# intervento ergoterapico Language.ITALIAN
# Eine Analyse Language.GERMAN
# apprendimento marzo Language.ITALIAN
# carriola Language.SPANISH
# valutazione annuale Language.ITALIAN
# sfera emozionale Language.ITALIAN
# movimenti mirror Language.ITALIAN
# valutazione autonoma Language.ITALIAN
# describe developmental trajectories Language.ENGLISH
# Federazione mondiale Language.ITALIAN
# organizzazione visuo Language.ITALIAN
# quoziente intellettivo Language.ITALIAN
# risultati scolastici migliori Language.ITALIAN
# Performance occupazionale Language.ITALIAN
# sviluppo motorio favorevole Language.ITALIAN
# livello scolastico Language.ITALIAN
# prognostic significance Language.ITALIAN
# dati empirici longitudinali Language.ITALIAN
# lavori scritti Language.ITALIAN
# aspetti strumentali Language.ITALIAN
# etichetta diagnostica Language.ITALIAN
# Prassie' Language.GERMAN
# sviluppo intellettivo Language.ITALIAN
# docente specificamente formato Language.ITALIAN
# valutazione oggettiva Language.ITALIAN
# ritardo mentale Language.ITALIAN
# interviste semi Language.ITALIAN
# disturbi pervasivi Language.ITALIAN
# Rivista americana Language.ITALIAN
# ritardo iniziale Language.ITALIAN
# forms Language.ENGLISH
# participation Language.FRENCH
# dati ottenuti Language.ITALIAN
# profiles Language.FRENCH
# Exercice Language.FRENCH
# circostanze psicosociali avverse Language.ITALIAN
# terapisti esterni Language.ITALIAN
# origine lesionale Language.ITALIAN
# funzioni sensorimotorie Language.ITALIAN
# Icelandic school Language.ENGLISH
# degree Language.ENGLISH
# Psychiatric Association Language.FRENCH
# Principi guida Language.SPANISH
# aree corticali Language.ENGLISH
# aree cerebrali Language.ITALIAN
# sintomatologia esternalizzante Language.ITALIAN
# aspetto cognitivo Language.ITALIAN
# competenze grafo Language.ITALIAN
# Attività creative Language.ITALIAN
# Andrwes Language.SPANISH
# influenze esogene negative Language.ITALIAN
# quadri clinici complessi Language.ITALIAN
# Rudelli University Language.ENGLISH
# shooting Language.ENGLISH
# Legge federale Language.ITALIAN
# cerniere Language.GERMAN
# pallone terapeutico Language.ITALIAN
# terapista occupazionale Language.ITALIAN
# ripercussioni socio Language.ITALIAN
# aspe strumentali Language.ITALIAN
# later motor Language.ENGLISH
# mathematical Language.ENGLISH
# direFamente Language.SPANISH
# Bright Language.ENGLISH
# pratica clinica Language.ITALIAN
# attività propriocettiva Language.ITALIAN
# Osservazioni cliniche Language.ITALIAN
# sviluppo psicopatologico Language.ITALIAN
# adolescence externalizing Language.ENGLISH
# rilevanza maggiore Language.ITALIAN
# Intervento ambientale Language.ITALIAN
# cogniBvo Language.SPANISH
# fascia gialla Language.ITALIAN
# attenzione sostenuta Language.ITALIAN
# applicazione diversiﬁ cate Language.ITALIAN
# orientamento spaziale Language.ITALIAN
# disfunzione cerebrale Language.ITALIAN
# Write Language.ENGLISH
# disturbi comportamentali Language.ITALIAN
# attività ludiche Language.ITALIAN
# Prassie Language.GERMAN
# rischio maggiore Language.ITALIAN
# difficoltà persistenti Language.ITALIAN
# allenamento fisico Language.ITALIAN
# oﬀerta ergoterapica Language.SPANISH
# efﬁcacia superiore Language.ITALIAN
# Schulische Inklusion Language.GERMAN
# stati emotivi Language.ITALIAN
# sofferenza perinatale Language.ITALIAN
# nascita superiore Language.ITALIAN
# lavoro visuospaziale Language.ITALIAN
# compromissione motoria interferisca Language.ITALIAN
# copiatura Language.ITALIAN
# livello borderline Language.ITALIAN
# funzionamento esecutivo Language.ITALIAN
# versus chairs Language.ENGLISH
# INSERIRE ALTRI Language.ITALIAN
# Depressive Language.ENGLISH
# assemblaggio Language.ITALIAN
# evidenza scientifica recente Language.ITALIAN
# campione ristretto Language.ITALIAN
# emotivo orato Language.ITALIAN
# difficoltà presenti Language.ITALIAN
# depression Language.ENGLISH
# riuscita scolastica Language.ITALIAN
# Zurich University Language.ENGLISH
# activity school Language.ENGLISH
# lezioni accademiche Language.ITALIAN
# interventi riabilitativi Language.ITALIAN
# Results Language.ENGLISH
# personale docente Language.ITALIAN
# behaviours Gior Language.ENGLISH
# componenti utili Language.ITALIAN
# attenzione particolare Language.ITALIAN
# Perceived Language.ENGLISH
# dato riscontrato Language.ITALIAN
# Strategie' Language.GERMAN
# intervista clinica Language.ITALIAN
# ottica professionale Language.ITALIAN
# riconoscimento precoce Language.ITALIAN
# abilità considerate Language.ITALIAN
# vista motorio Language.ITALIAN
# rispePvi sistemi Language.ITALIAN
# banding Language.ENGLISH
# scuola inclusiva Language.ITALIAN
# evaluation Language.ENGLISH
# obiePvo Language.GERMAN
# Preschool Language.ENGLISH
# clinical variations Language.ENGLISH
# impegno strategico Language.ITALIAN
# Quelles pratiques Language.FRENCH
# incontri regolari Language.ITALIAN
# maniera differente Language.ITALIAN
# Neurodevelopmental outcomes Language.ENGLISH
# controllo posturale Language.ITALIAN
# empathy Language.ENGLISH
# studi epidemiologici Language.ITALIAN
# cammino inclusivo Language.ITALIAN
# inﬂuenza positiva Language.ENGLISH
# funzioni oculo Language.ITALIAN
# {'motricità': {'f': '36'}, 'funzioni esecutive': {'f': '33'}, 'coordinazione motoria': {'f': '16'}, 'valutazione iniziale': {'f': '14'}, 'attività fisica': {'f': '12'}, 'controllo emotivo': {'f': '12'}, 'pianiﬁcazione': {'f': '10'}, 'motricità fine': {'f': '10'}, 'pretermine': {'f': '9'}, 'problemi psicopatologici': {'f': '9'}, 'abilità motorie': {'f': '8'}, 'Comorbidità': {'f': '7'}, 'ﬂessibilità': {'f': '7'}, 'categorie motricità': {'f': '7'}, 'modo significativo': {'f': '7'}, 'categoria equilibrio': {'f': '7'}, 'aPvità': {'f': '7'}, 'coltà': {'f': '6'}, 'inattenzione': {'f': '6'}, 'Comorbidità psicopatologica': {'f': '6'}, 'quadri clinici': {'f': '6'}, 'iperattività': {'f': '6'}, 'situazione iniziale': {'f': '5'}, 'disturbi esternalizzanti': {'f': '5'}, 'sviluppo motorio': {'f': '5'}, 'difficoltà motorie': {'f': '5'}, 'Neurol': {'f': '5'}, 'allenamento motorio': {'f': '5'}, 'legame positivo': {'f': '5'}, 'scuola regolare': {'f': '5'}, 'comportamenti esternalizzanti': {'f': '5'}, 'Carasso': {'f': '5'}, 'segni neurologici minori': {'f': '4'}, 'intervento specialistico': {'f': '4'}, 'disturbi psicopatologici': {'f': '4'}, 'esternalizzanti': {'f': '4'}, 'motricità globale': {'f': '4'}, 'problemi psicopatologici lievi': {'f': '4'}, 'evoluzione signiﬁcativa': {'f': '4'}, 'QUFE Genitori': {'f': '4'}, 'risultati scolastici': {'f': '4'}, 'complicanze psicopatologiche': {'f': '4'}, 'funzioni motorie': {'f': '3'}, 'competenze posturali': {'f': '3'}, 'tipo internalizzante': {'f': '3'}, 'sostanza bianca': {'f': '3'}, 'gruppo sperimentale': {'f': '3'}, 'attività motorie': {'f': '3'}, 'rendimento scolastico': {'f': '3'}, 'evoluzione favorevole': {'f': '3'}, 'stimolazione motoria quotidiana': {'f': '3'}, 'sintomatologia depressiva': {'f': '3'}, 'tendenza significativa': {'f': '3'}, 'apprendimento scolastico': {'f': '3'}, 'progetto pilota': {'f': '3'}, 'nascita pretermine': {'f': '3'}, 'evidenze empiriche': {'f': '3'}, 'attività motoria': {'f': '3'}, 'terapia occupazionale': {'f': '3'}, 'abilità grafo': {'f': '3'}, 'categorie iniziativa': {'f': '3'}, 'popolazione clinica': {'f': '3'}, 'ambito motorio': {'f': '3'}, 'efﬁcacia': {'f': '2'}, 'dimensione evolutiva': {'f': '2'}, 'abilità sociali': {'f': '2'}, 'database elettronici': {'f': '2'}, 'evidenze scientifiche': {'f': '2'}, 'Allegrante': {'f': '2'}, 'bambini sani': {'f': '2'}, 'grafomotricità': {'f': '2'}, 'eziopatogenesi': {'f': '2'}, 'ergoterapiste': {'f': '2'}, 'popolazione specifica': {'f': '2'}, 'funzionamento cognitivo': {'f': '2'}, 'studio esplorativo': {'f': '2'}, 'endofenotipo': {'f': '2'}, 'funzionamento sociale': {'f': '2'}, 'risultati simili': {'f': '2'}, 'soggetti nati': {'f': '2'}, 'risultati accademici': {'f': '2'}, 'categorie seguenti': {'f': '2'}, 'monozigoti': {'f': '2'}, 'numero ridotto': {'f': '2'}, 'categorie motricità fine': {'f': '2'}, 'attività fisica quotidiana': {'f': '2'}, 'relazione positiva': {'f': '2'}, 'terapista': {'f': '2'}, 'categoria attenzione': {'f': '2'}, 'successo scolastico': {'f': '2'}, 'base probabilistica': {'f': '2'}, 'effetto positivo': {'f': '2'}, 'traiettorie evolutive': {'f': '2'}, 'funzioni deficitarie': {'f': '2'}, 'ﬁnanziamento': {'f': '2'}, 'impulsività': {'f': '2'}, 'popolazione generale': {'f': '2'}, 'Camaiore': {'f': '2'}, 'fibre interemisferiche': {'f': '2'}, 'prestazioni motorie': {'f': '2'}, 'sviluppo maggiore': {'f': '2'}, 'scuola regolare svizzera': {'f': '2'}, 'programma proposto': {'f': '2'}, 'SEQUENZIALE': {'f': '2'}, 'condizione medica': {'f': '2'}, 'Centrati': {'f': '2'}, 'assessor': {'f': '2'}, 'attività proposte': {'f': '2'}, 'disturbi psichiatrici': {'f': '2'}, 'compiti scolastici': {'f': '2'}, 'disturbi internalizzanti': {'f': '2'}, 'risultati preliminari': {'f': '2'}, 'comportamenti iperattivi': {'f': '2'}, 'giornata scolastica': {'f': '2'}, 'categorie controllo emotivo': {'f': '2'}, 'valutazione finale': {'f': '2'}, 'espressività psicopatologica': {'f': '1'}, 'retest': {'f': '1'}, 'problemi comportamentali seri': {'f':  ...

# %%
print(lemmatize_terms(example, "ita"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 print(lemmatize_terms(example, "ita"))
#
# Input In [7], in lemmatize_terms(terms, lang)
#       3 lemmatized_terms = {}
#       5 pipe = spacy.load(spacy_models[lang]["sm"])
# ----> 7 term_list_old = list(terms.keys())
#       9 for term in term_list_old:
#      11 	doc = pipe(term)
#
# AttributeError: 'list' object has no attribute 'keys'
